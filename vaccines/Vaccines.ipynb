# %%
import pandas as pd
import numpy as np
import glob

# %%
datadir = '/Users/xthomas/Documents/data/cdc.gov_pub_HealthStatistics_NCHS/'

# %%
glob.glob(datadir + '*.*')
# Out:
# ['/Users/xthomas/Documents/data/cdc.gov_pub_HealthStatistics_NCHS/nispuf14.dat',
#  '/Users/xthomas/Documents/data/cdc.gov_pub_HealthStatistics_NCHS/original-url.txt']

# %%
df1 = pd.read_csv(datadir + 'nispuf14.dat', header = None,  skiprows = 1)

# %%
df1
# Out:
#                                                        0
# 0      000021000021 806.84601169505000 806.8460116950...
# 1      000031000032    .                  .          ...
# 2      000041000041  63.44868567610260  63.4486856761...
# 3      000051000051  94.87263225744540  94.8726322574...
# 4      000052000051 152.27384456301200 152.2738445630...
# 5      000061000061 210.18635053571600 210.1863505357...
# 6      000071000071 204.95333635300500 204.9533363530...
# 7      0000810000811016.753530684230001016.7535306842...
# 8      000091000092    .                  .          ...
# 9      000101000102    .                  .          ...
# 10     000111000111 390.53258512793300 390.5325851279...
# 11     000121000121 248.74551042628700 248.7455104262...
# 12     000131000131 489.06486358946900 489.0648635894...
# 13     000141000142    .                  .          ...
# 14     000151000151  18.55400999271240  18.5540099927...
# ...

# %%
df2 = np.genfromtxt(datadir + 'nispuf14.dat', dtype=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-62e68702d513> in <module>()
# ----> 1 df2 = np.genfromtxt(datadir + 'nispuf14.dat', dtype=None)
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2012             # Raise an exception ?
#    2013             if invalid_raise:
# -> 2014                 raise ValueError(errmsg)
#    2015             # Issue a warning ?
#    2016             else:
#
# ValueError: Some errors were detected !
#     Line #2 (got 136 columns instead of 131)
#     Line #3 (got 135 columns instead of 131)
#     Line #4 (got 136 columns instead of 131)
# ...

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2068723f1203> in <module>()
# ----> 1 df2
#
# NameError: name 'df2' is not defined
