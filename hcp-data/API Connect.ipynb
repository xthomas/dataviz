# %%
import pandas as pd
url = 'https://data.cms.gov/resource/4hzz-sw77.csv'
df = pd.read_csv(url)

# %%
df.shape
# Out:
# (1000, 26)

# %%
df
# Out:
#      average_medicare_allowed_amt  average_medicare_payment_amt  \
# 0                       72.680000                     54.502609
# 1                      135.850000                    100.958889
# 2                      101.365085                     79.469661
# 3                      139.010455                    107.933409
# 4                      205.185955                    157.908955
# 5                       39.554737                     31.015789
# 6                       73.251164                     56.313859
# 7                      105.481845                     80.929379
# 8                       73.987143                     57.079486
# 9                      108.860516                     83.947201
# 10                     227.058571                    178.011905
# 11                      12.451954                      9.276169
# 12                      40.313044                     30.128253
# 13                      28.946283                     22.054049
# ...

# %%
list(df)
# Out:
# ['average_medicare_allowed_amt',
#  'average_medicare_payment_amt',
#  'average_medicare_standard_amt',
#  'average_submitted_chrg_amt',
#  'bene_day_srvc_cnt',
#  'bene_unique_cnt',
#  'hcpcs_code',
#  'hcpcs_description',
#  'hcpcs_drug_indicator',
#  'line_srvc_cnt',
#  'medicare_participation_indicator',
#  'npi',
#  'nppes_credentials',
#  'nppes_entity_code',
#  'nppes_provider_city',
#  'nppes_provider_country',
#  'nppes_provider_first_name',
#  'nppes_provider_gender',
#  'nppes_provider_last_org_name',
#  'nppes_provider_mi',
#  'nppes_provider_state',
#  'nppes_provider_street1',
#  'nppes_provider_street2',
#  'nppes_provider_zip',
#  'place_of_service',
#  'provider_type']

# %%
# speciality = dfOne.groupby('Primary specialty').size().reset_index(name='count')
# speciality.sort_values(by='count', ascending=False,inplace=True)
# speciality
speciality = df.groupby('provider_type').size().reset_index(name='count')
speciality.sort_values(by='count', ascending=False,inplace=True)
speciality
# Out:
#                                   provider_type  count
# 29                            Internal Medicine    130
# 16                         Diagnostic Radiology    125
# 19                              Family Practice    123
# 8                                    Cardiology     50
# 40                           Nurse Practitioner     43
# 46                           Orthopedic Surgery     35
# 49                                    Pathology     28
# 43                                Ophthalmology     28
# 52                          Physician Assistant     26
# 65                                      Urology     23
# 22                              General Surgery     23
# 3                                Anesthesiology     22
# 51                           Physical Therapist     22
# 27                          Hematology/Oncology     19
# 54                                     Podiatry     17
# 44                                    Optometry     17
# ...
