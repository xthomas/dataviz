# %%
import pandas as pd

# %%
# load NPI data
npidir = '/Users/xthomas/Documents/data/download.cms.gov_nppes_npi-files/'
latest_headers = 'npidata_pfile_20050523-20180408_FileHeader.csv'
latest = 'npidata_pfile_20050523-20180408.csv'

fields = ['NPI',
 'Entity Type Code',
 'Provider Organization Name (Legal Business Name)',
 'Provider First Line Business Mailing Address',
 'Provider First Line Business Practice Location Address',          
 'Healthcare Provider Taxonomy Code_1',
 'Healthcare Provider Taxonomy Code_2', 
 'Healthcare Provider Taxonomy Code_3',
 'Healthcare Provider Taxonomy Code_4',
 'Healthcare Provider Taxonomy Code_5',
 'Healthcare Provider Taxonomy Code_6',
 'Healthcare Provider Taxonomy Code_7',  
 'Healthcare Provider Taxonomy Code_8',
 'Healthcare Provider Taxonomy Code_9', 
 'Healthcare Provider Taxonomy Code_10', 
 'Healthcare Provider Taxonomy Code_11', 
 'Healthcare Provider Taxonomy Code_12', 
 'Healthcare Provider Taxonomy Code_13', 
 'Healthcare Provider Taxonomy Code_14',
 'Healthcare Provider Taxonomy Code_15',   
 'Is Organization Subpart',
 'Parent Organization LBN',
 'Parent Organization TIN']

# fields = ['NPI',
#  'Entity Type Code',
#  'Employer Identification Number (EIN)',
#  'Provider Organization Name (Legal Business Name)']

# %%
# Preview all the columns
npi_preview = pd.read_csv(npidir + latest_headers)
list(npi_preview)

# %%
# only load the columsn we need for now
npi = pd.read_csv(npidir + latest, usecols = fields)
list(npi)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (67,71,75,79,83,87,91,95,99,103) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ['NPI',
#  'Entity Type Code',
#  'Provider Organization Name (Legal Business Name)',
#  'Provider First Line Business Mailing Address',
#  'Provider First Line Business Practice Location Address',
#  'Healthcare Provider Taxonomy Code_1',
#  'Healthcare Provider Taxonomy Code_2',
#  'Healthcare Provider Taxonomy Code_3',
#  'Healthcare Provider Taxonomy Code_4',
#  'Healthcare Provider Taxonomy Code_5',
#  'Healthcare Provider Taxonomy Code_6',
#  'Healthcare Provider Taxonomy Code_7',
#  'Healthcare Provider Taxonomy Code_8',
#  'Healthcare Provider Taxonomy Code_9',
#  'Healthcare Provider Taxonomy Code_10',
#  'Healthcare Provider Taxonomy Code_11',
#  'Healthcare Provider Taxonomy Code_12',
# ...

# %%
npi.shape
# Out:
# (5546685, 23)

# %% [markdown]
# # 5,546,685 rows of Organizations

# %%
research_clinics = npi[
            (npi["Healthcare Provider Taxonomy Code_1" ]=="261QR1100X") | 
            (npi["Healthcare Provider Taxonomy Code_2" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_3" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_4" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_5" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_6" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_7" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_8" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_9" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_10" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_11" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_12" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_13" ]=="261QR1100X") |
            (npi["Healthcare Provider Taxonomy Code_14" ]=="261QR1100X") |        
            (npi["Healthcare Provider Taxonomy Code_15" ]=="261QR1100X")    
            ]
research_clinics.shape
# Out:
# (215, 23)

# %%
research_clinics
# Out:
#                 NPI  Entity Type Code  \
# 450251   1013971381               2.0
# 533279   1508817396               2.0
# 633125   1639110042               2.0
# 906700   1386658615               2.0
# 999023   1073627360               2.0
# 1000424  1699889832               2.0
# 1040496  1386752079               2.0
# 1278259  1790875763               2.0
# 1643361  1366594699               2.0
# 1644170  1265585806               2.0
# 1648512  1720131485               2.0
# 1821023  1831227925               2.0
# 1933995  1568580355               2.0
# 1951358  1295855542               2.0
# 1980313  1700909207               2.0
# 2003712  1962626341               2.0
# 2096225  1578777694               2.0
# 2100735  1306050059               2.0
# 2143573  1114135019               2.0
# 2170905  1457562746               2.0
# 2187889  1669674552               2.0
# 2216868  1619172970               2.0
# 2225397  1376749994               2.0
# ...

# %% [markdown]
# # 215 Research Clinics
#
# Chosen [from this list](http://nucc.org/index.php/code-sets-mainmenu-41/provider-taxonomy-mainmenu-40/code-lookup-mainmenu-50) for the _'Research' sound_ of category:
#
# + Clinical Medical Laboratory - 291U00000X [definition]
# + Research - 261QR1100X [definition]
# + Medical Genetics, Ph.D. Medical Genetics - 170100000X [definition]
# + Research Study - 1744R1102X [definition]
# + Molecular Genetic Pathology - 207ZP0007X [definition]
# + Clinical Biochemical Genetics - 207SG0202X [definition]
# + Clinical Cytogenetic - 207SC0300X [definition]
# + Clinical Genetics (M.D.) - 207SG0201X [definition]
# + Clinical Molecular Genetics - 207SG0203X [definition]
# + Molecular Genetic Pathology - 207SM0001X [definition]
# + Ph.D. Medical Genetics - 207SG0205X [definition]

# %%
research_clinics.to_csv(datadir + '215_research_clinics.csv')

# %%
datadir = '/Users/xthomas/Documents/data/data.cms.gov_Medicare-Physician-Supplier/sliced/'
tumors = pd.read_csv(datadir + '4126_tumor_claims.csv')

# %%
list(tumors)
# Out:
# ['INDEX', 'ADDRESS']

# %%
tumor_addresses = pd.Series(tumors.ADDRESS)
tumor_addresses.to_csv
# Out:
# 0                   2650 RIDGE AVE
# 1                   251 E HURON ST
# 2                3426 BRAEBURN CIR
# 3                3426 BRAEBURN CIR
# 4             3600 NW SAMARITAN DR
# 5            660 N WESTMORELAND RD
# 6                   2160 S 1ST AVE
# 7           601 WEST SECOND STREET
# 8                   600 N WOLFE ST
# 9               1959 NE PACIFIC ST
# 10              535 E CRESCENT AVE
# 11                    1638 OWEN DR
# 12                   901 MACARTHUR
# 13                 90 S BEDFORD RD
# 14           2904 WESTCORP BLVD SW
# 15           2904 WESTCORP BLVD SW
# 16                   300 HALKET ST
# 17           619 19TH STREET SOUTH
# 18               5301 VIRGINIA WAY
# 19             1 MEDICAL CENTER DR
# 20                    1 HOAG DRIVE
# 21                  2411 HOLMES ST
# 22                 1007 LINCOLNWAY
# 23                1500 E DUARTE RD
# 24           75 FRANCIS ST AMORY 3
# 25                    100 GRAND ST
# 26                    655 W 8TH ST
# ...

# %%
research_clinics['Provider First Line Business Mailing Address'].isin(tumor_addresses).value_counts()
# Out:
# False    212
# True       3
# Name: Provider First Line Business Mailing Address, dtype: int64

# %%
research_clinics['Provider First Line Business Mailing Address'].isin(tumor_addresses)
# Out:
# 450251     False
# 533279     False
# 633125     False
# 906700     False
# 999023     False
# 1000424    False
# 1040496    False
# 1278259    False
# 1643361    False
# 1644170    False
# 1648512    False
# 1821023     True
# 1933995    False
# 1951358    False
# 1980313    False
# 2003712    False
# 2096225    False
# 2100735    False
# 2143573    False
# 2170905    False
# 2187889    False
# 2216868    False
# 2225397    False
# 2283143    False
# 2478743    False
# 2688157    False
# 2699327    False
# 2710545    False
# 2738844    False
# 2744297    False
#            ...
# 5030644    False
# 5040698    False
# 5041215    False
# 5064923    False
# 5071634    False
# 5102009    False
# 5152760    False
# 5187507    False
# 5220811    False
# 5220814    False
# 5261307    False
# 5286418    False
# 5290771    False
# 5294389    False
# 5316029    False
# 5337797    False
# 5371409    False
# 5374765    False
# 5378065    False
# 5378601    False
# 5381426    False
# ...

# %% [markdown]
# # "Community Oncology Clinics"
#
# Codes from the [Provider Taxonomy](http://nucc.org/index.php/code-sets-mainmenu-41/provider-taxonomy-mainmenu-40/code-lookup-mainmenu-50)codex:
#
# + Oncology - 261QX0200X [definition]
# + Oncology, Radiation - 261QX0203X [definition]
# + Medical Oncology - 207RX0202X [definition]
# + Hematology & Oncology - 207RH0003X [definition]
# + Pediatric Hematology-Oncology - 2080P0207X [definition]
# + Radiation Oncology - 2085R0001X [definition]
# + Surgical Oncology - 2086X0206X [definition]
# + Oncology - 261QX0200X [definition]

# %%
oncology_clinics = npi[
            (npi["Healthcare Provider Taxonomy Code_1"]=="261QX0200X") |
            (npi["Healthcare Provider Taxonomy Code_1"]=="261QX0203X") |
            (npi["Healthcare Provider Taxonomy Code_1"]=="207RX0202X") |
            (npi["Healthcare Provider Taxonomy Code_1"]=="207RH0003X") |
            (npi["Healthcare Provider Taxonomy Code_1"]=="2080P0207X") |
            (npi["Healthcare Provider Taxonomy Code_1"]=="2085R0001X") |
            (npi["Healthcare Provider Taxonomy Code_1"]=="2086X0206X") |
            (npi["Healthcare Provider Taxonomy Code_1"]=="261QX0200X") 
            ]
oncology_clinics.shape
# Out:
# (25659, 23)

# %%
# oncology_clinics = npi[
#             (npi["Healthcare Provider Taxonomy Code_1"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_1"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_1"]=="207RX0202X") |
#             (npi["Healthcare Provider Taxonomy Code_1"]=="207RH0003X") |
#             (npi["Healthcare Provider Taxonomy Code_1"]=="2080P0207X") |
#             (npi["Healthcare Provider Taxonomy Code_1"]=="2085R0001X") |
#             (npi["Healthcare Provider Taxonomy Code_1"]=="2086X0206X") |
#             (npi["Healthcare Provider Taxonomy Code_1"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_2"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_2"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_2"]=="207RX0202X") |
#             (npi["Healthcare Provider Taxonomy Code_2"]=="207RH0003X") |
#             (npi["Healthcare Provider Taxonomy Code_2"]=="2080P0207X") |
#             (npi["Healthcare Provider Taxonomy Code_2"]=="2085R0001X") |
#             (npi["Healthcare Provider Taxonomy Code_2"]=="2086X0206X") |
#             (npi["Healthcare Provider Taxonomy Code_2"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_3"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_3"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_3"]=="207RX0202X") |
#             (npi["Healthcare Provider Taxonomy Code_3"]=="207RH0003X") |
#             (npi["Healthcare Provider Taxonomy Code_3"]=="2080P0207X") |
#             (npi["Healthcare Provider Taxonomy Code_3"]=="2085R0001X") |
#             (npi["Healthcare Provider Taxonomy Code_3"]=="2086X0206X") |
#             (npi["Healthcare Provider Taxonomy Code_3"]=="261QX0200X") |    
#             (npi["Healthcare Provider Taxonomy Code_4"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_4"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_4"]=="207RX0202X") |
#             (npi["Healthcare Provider Taxonomy Code_4"]=="207RH0003X") |
#             (npi["Healthcare Provider Taxonomy Code_4"]=="2080P0207X") |
#             (npi["Healthcare Provider Taxonomy Code_4"]=="2085R0001X") |
#             (npi["Healthcare Provider Taxonomy Code_4"]=="2086X0206X") |
#             (npi["Healthcare Provider Taxonomy Code_4"]=="261QX0200X") |    
#             (npi["Healthcare Provider Taxonomy Code_5"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_5"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_5"]=="207RX0202X") |
#             (npi["Healthcare Provider Taxonomy Code_5"]=="207RH0003X") |
#             (npi["Healthcare Provider Taxonomy Code_5"]=="2080P0207X") |
#             (npi["Healthcare Provider Taxonomy Code_5"]=="2085R0001X") |
#             (npi["Healthcare Provider Taxonomy Code_5"]=="2086X0206X") |
#             (npi["Healthcare Provider Taxonomy Code_5"]=="261QX0200X") |    
#             (npi["Healthcare Provider Taxonomy Code_6"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_6"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_6"]=="207RX0202X") |
#             (npi["Healthcare Provider Taxonomy Code_6"]=="207RH0003X") |
#             (npi["Healthcare Provider Taxonomy Code_6"]=="2080P0207X") |
#             (npi["Healthcare Provider Taxonomy Code_6"]=="2085R0001X") |
#             (npi["Healthcare Provider Taxonomy Code_6"]=="2086X0206X") |
#             (npi["Healthcare Provider Taxonomy Code_6"]=="261QX0200X") |    
#             (npi["Healthcare Provider Taxonomy Code_7"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_7"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_7"]=="207RX0202X") |
#             (npi["Healthcare Provider Taxonomy Code_7"]=="207RH0003X") |
#             (npi["Healthcare Provider Taxonomy Code_7"]=="2080P0207X") |
#             (npi["Healthcare Provider Taxonomy Code_7"]=="2085R0001X") |
#             (npi["Healthcare Provider Taxonomy Code_7"]=="2086X0206X") |
#             (npi["Healthcare Provider Taxonomy Code_7"]=="261QX0200X") |    
#             (npi["Healthcare Provider Taxonomy Code_8"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_8"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_8"]=="207RX0202X") |
#             (npi["Healthcare Provider Taxonomy Code_8"]=="207RH0003X") |
#             (npi["Healthcare Provider Taxonomy Code_8"]=="2080P0207X") |
#             (npi["Healthcare Provider Taxonomy Code_8"]=="2085R0001X") |
#             (npi["Healthcare Provider Taxonomy Code_8"]=="2086X0206X") |
#             (npi["Healthcare Provider Taxonomy Code_8"]=="261QX0200X") |    
#             (npi["Healthcare Provider Taxonomy Code_9"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_9"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_9"]=="207RX0202X") |
#             (npi["Healthcare Provider Taxonomy Code_9"]=="207RH0003X") |
#             (npi["Healthcare Provider Taxonomy Code_9"]=="2080P0207X") |
#             (npi["Healthcare Provider Taxonomy Code_9"]=="2085R0001X") |
#             (npi["Healthcare Provider Taxonomy Code_9"]=="2086X0206X") |
#             (npi["Healthcare Provider Taxonomy Code_9"]=="261QX0200X") 
#             ]
# oncology_clinics.shape
# Out:
# (32800, 23)

# %%
oncology_clinics.to_csv(datadir + '25659oncology-clinics.csv' )

# %%
#             (npi["Healthcare Provider Taxonomy Code_2"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_2"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_3"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_3"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_4"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_4"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_5"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_5"]=="261QX0203X") |    
#             (npi["Healthcare Provider Taxonomy Code_6"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_6"]=="261QX0203X") |    
#             (npi["Healthcare Provider Taxonomy Code_7"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_7"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_8"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_8"]=="261QX0203X") |    
#             (npi["Healthcare Provider Taxonomy Code_9"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_9"]=="261QX0203X") |
#             (npi["Healthcare Provider Taxonomy Code_10"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_11"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_12"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_13"]=="261QX0200X") |
#             (npi["Healthcare Provider Taxonomy Code_14"]=="261QX0200X") |        
#             (npi["Healthcare Provider Taxonomy Code_15"]=="261QX0200X")
