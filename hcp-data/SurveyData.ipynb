# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
datadir = '/Users/xthomas/Documents/data/data.medicare.gov_data_archives_physician-compare/'
datafileOne = 'National_Downloadable_File.csv'
datafileTwo = 'Physician_Compare_2015_Individual_EP_Public_Reporting___Performance_Scores.csv'
dfOne = pd.read_csv(datadir + datafileOne)
dfTwo = pd.read_csv(datadir + datafileTwo)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (15,26,28,30,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dfOne.shape
# Out:
# (2001890, 40)

# %%
list(dfOne)
# Out:
# ['NPI',
#  'PAC ID',
#  'Professional Enrollment ID',
#  'Last Name',
#  'First Name',
#  'Middle Name',
#  'Suffix',
#  'Gender',
#  'Credential',
#  'Medical school name',
#  'Graduation year',
#  'Primary specialty',
#  'Secondary specialty 1',
#  'Secondary specialty 2',
#  'Secondary specialty 3',
#  'Secondary specialty 4',
#  'All secondary specialties',
#  'Organization legal name',
#  'Group Practice PAC ID',
#  'Number of Group Practice members',
#  'Line 1 Street Address',
#  'Line 2 Street Address',
#  'Marker of address line 2 suppression',
#  'City',
#  'State',
#  'Zip Code',
#  'Claims based hospital affiliation CCN 1',
#  'Claims based hospital affiliation LBN 1',
#  'Claims based hospital affiliation CCN 2',
#  'Claims based hospital affiliation LBN 2',
#  'Claims based hospital affiliation CCN 3',
#  'Claims based hospital affiliation LBN 3',
#  'Claims based hospital affiliation CCN 4',
#  'Claims based hospital affiliation LBN 4',
# ...

# %%
dfTwo.shape
# Out:
# (495417, 10)

# %%
list(dfTwo)
# Out:
# ['NPI',
#  'PAC ID',
#  'Last Name',
#  'First Name',
#  'Measure Identifier',
#  'Measure Title',
#  'Inverse Measure',
#  'Measure Performance Rate',
#  'Reporting Mechanism',
#  'Reported on PC Live Site']

# %%
dfTwo.head(10)
# Out:
#           NPI    PAC ID Last Name First Name Measure Identifier  \
# 0  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_110_1
# 1  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_111_1
# 2  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_112_1
# 3  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_113_1
# 4  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_128_1
# 5  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_130_1
# 6  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_181_1
# 7  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_226_1
# 8  1508823618  42100117   GRIFFIN      DAVID       PQRS_EP_39_1
# 9  1477528776  42100133     SPEAR    JEFFREY      PQRS_EP_317_1
#
#                                        Measure Title Inverse Measure  \
# 0  Preventive Care and Screening: Influenza Immun...               N
# 1      Pneumonia Vaccination Status for Older Adults               N
# ...

# %%
speciality = dfOne.groupby('Primary specialty').size().reset_index(name='count')
speciality.sort_values(by='count', ascending=False,inplace=True)
speciality
# Out:
#                                     Primary specialty   count
# 32                                  INTERNAL MEDICINE  237406
# 20                                    FAMILY PRACTICE  178295
# 43                                 NURSE PRACTITIONER  163809
# 17                               DIAGNOSTIC RADIOLOGY   86937
# 9              CERTIFIED REGISTERED NURSE ANESTHETIST   75775
# 57                                 PHYSICAL THERAPIST   75273
# 7                 CARDIOVASCULAR DISEASE (CARDIOLOGY)   71534
# 44                              OBSTETRICS/GYNECOLOGY   70305
# 2                                      ANESTHESIOLOGY   70091
# 10                                       CHIROPRACTIC   58650
# 13                             CLINICAL SOCIAL WORKER   58085
# 62                                         PSYCHIATRY   56762
# 12                              CLINICAL PSYCHOLOGIST   52939
# 23                                    GENERAL SURGERY   49229
# ...

# %%
quality = dfTwo.groupby('Measure Title').size().reset_index(name='total')
quality.sort_values(by='total', ascending=False,inplace=True)
quality
# Out:
#                                          Measure Title  total
# 48   Documentation of Current Medications in the Me...  64816
# 98   Preventive Care and Screening: Tobacco Use: Sc...  40673
# 94   Preventive Care and Screening: Body Mass Index...  38491
# 81                       Pain Assessment and Follow-Up  35793
# 89                Perioperative Temperature Management  31189
# 58                       Functional Outcome Assessment  24690
# 92       Pneumonia Vaccination Status for Older Adults  19722
# 95   Preventive Care and Screening: Influenza Immun...  16854
# 97   Preventive Care and Screening: Screening for H...  15454
# 36                         Colorectal Cancer Screening  15215
# 99   Preventive Care and Screening: Unhealthy Alcoh...  14239
# 25                             Breast Cancer Screening  13004
# 104  Radiology: Exposure Time Reported for Procedur...  11305
# 123       Use of High-Risk Medications in the Elderly*  10996
# ...
