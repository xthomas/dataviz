# %%
# Just a basic configuration
import pandas as pd

# %%
sixteen='./csv_data/2016_inc5k.csv'
fifteen='./csv_data/2015_inc5k.csv'
fourteen='./csv_data/2014_inc5k.csv'
thirteen='./csv_data/2013_inc5k.csv'
df16 = pd.read_csv(sixteen).rename(columns=str.lower)
df16['company'] = df16['company'].str.lower()
df16.name = 'df16'
df15 = pd.read_csv(fifteen).rename(columns=str.lower)
df15['company'] = df15['company'].str.lower()
df15.name = 'df15'
df14 = pd.read_csv(fourteen).rename(columns=str.lower)
df14['company'] = df14['company'].str.lower()
df14.name = 'df14'
df13 = pd.read_csv(thirteen).rename(columns=str.lower)
df13['company'] = df13['company'].str.lower()
df13.name = 'df13'
df13
# Out:
#       unnamed: 0               city               state_l  \
# 0              0         El Segundo            California
# 1              1           Dumfries              Virginia
# 2              2       Jacksonville               Florida
# 3              3         Carrollton                 Texas
# 4              4             Boston         Massachusetts
# 5              5             Austin                 Texas
# 6              6          Nashville             Tennessee
# 7              7      San Francisco            California
# 8              8          Bluffdale                  Utah
# 9              9            Warwick          Rhode Island
# 10            10             Vienna              Virginia
# 11            11      San Francisco            California
# 12            12            Orlando               Florida
# 13            13         Charleston        South Carolina
# 14            14         Washington  District of Columbia
# ...

# %%
eventmarketer='./csv_data/study-list.csv'
#eventmarketer='./csv_data/new-it-list.csv'
#eventmarketer='./csv_data/it-list.csv'
#eventmarketer='./csv_data/rewritten-itlist.csv'
emdf = pd.read_csv(eventmarketer).rename(columns=str.lower)
emdf['company'] = emdf['company'].str.lower()
emdf.name = 'emdf'
#emdf = pd.read_csv(eventmarketer)
emdf
# Out:
#                         company  \
# 0            activent marketing
# 1       advantage international
# 2                      agencyea
# 3                   all terrain
# 4           allied experiential
# 5                 astound group
# 6         barkley kalpak agency
# 7                     bmf media
# 8          bolt marketing group
# 9        bottlerocket marketing
# 10                  broadstreet
# 11                    c3 agency
# 12   cardenas marketing network
# 13                       cramer
# 14               division black
# 15                    driveshop
# 16                  elemento l2
# 17        elite marketing group
# 18                         emg3
# 19                  engine shop
# 20                      epsilon
# 21         event strategy group
# 22                     eventage
# 23                     eventive
# 24                    eventnext
# 25       executive visions inc.
# 26                  factory 360
# 27                         fcbx
# ...

# %%
# affordable
radar16 = df16[(df16['revenue'].astype('int') > 999999) & (df16['revenue'].astype('int') < 39999999)]
radar15 = df15[(df15['revenue'].astype('int') > 999999) & (df15['revenue'].astype('int') < 39999999)]
radar14 = df14[(df14['revenue'].astype('int') > 999999) & (df14['revenue'].astype('int') < 39999999)]
radar13 = df13[(df13['revenue'].astype('int') > 999999) & (df13['revenue'].astype('int') < 39999999)]

# %%
# advertising and marketing
agencies16 = radar16[(radar16['industry'] == "Advertising & Marketing")]
agencies15 = radar15[(radar15['industry'] == "Advertising & Marketing")]
agencies14 = radar14[(radar14['industry'] == "Advertising & Marketing")]
agencies13 = radar13[(radar13['industry'] == "Advertising & Marketing")]

# %% [markdown]
# - - -
# > Ok—there are more in the metro of SF than in the city, so let's start there...

# %%
# in California
bayarea16 = agencies16[(agencies16['metro'] == "San Francisco")]
bayarea15 = agencies15[(agencies15['metro'] == "San Francisco")]
bayarea14 = agencies14[(agencies14['metro'] == "San Francisco")]
bayarea13 = agencies13[(agencies13['metro'] == "San Francisco")]

# %%
# in California
tristate16 = agencies16[(agencies16['metro'] == "New York City")]
tristate15 = agencies15[(agencies15['metro'] == "New York City")]
tristate14 = agencies14[(agencies14['metro'] == "New York City")]
tristate13 = agencies13[(agencies13['metro'] == "New York City")]

# %%
ind = bayarea16.company.isin(emdf.company)
ind
# Out:
# 291     False
# 539     False
# 716     False
# 900     False
# 1114    False
# 1493    False
# 1588    False
# 1703    False
# 1769    False
# 2183    False
# 2867    False
# 3088    False
# 3103    False
# 3183     True
# 4003    False
# 4012    False
# 4054    False
# Name: company, dtype: bool

# %%
bayarea16.shape
# Out:
# (17, 16)

# %%
bayarea16.isin(['manifold'])
# Out:
#      unnamed: 0   city state_l  metro revenue    url industry workers   rank  \
# 291       False  False   False  False   False  False    False   False  False
# 539       False  False   False  False   False  False    False   False  False
# 716       False  False   False  False   False  False    False   False  False
# 900       False  False   False  False   False  False    False   False  False
# 1114      False  False   False  False   False  False    False   False  False
# 1493      False  False   False  False   False  False    False   False  False
# 1588      False  False   False  False   False  False    False   False  False
# 1703      False  False   False  False   False  False    False   False  False
# 1769      False  False   False  False   False  False    False   False  False
# 2183      False  False   False  False   False  False    False   False  False
# 2867      False  False   False  False   False  False    False   False  False
# ...

# %%
bayarea16[bayarea16['company']=='manifold']
# Out:
#       unnamed: 0           city     state_l          metro   revenue  \
# 3183        3183  San Francisco  California  San Francisco  14863448
#
#            url                 industry  workers  rank     id  yrs_on_list  \
# 3183  manifold  Advertising & Marketing       16  3183  44172            1
#
#         growth  ifmid  ifiid state_s   company
# 3183  105.7138      4      5      CA  manifold

# %%
emdf[emdf['company']=='manifold']
# Out:
#      company                                               tags
# 58  manifold  all buzz-influencer-programs developer-confere...

# %%
common = set.intersection(set(bayarea16.company), set(emdf.company))
common
# Out:
# {'manifold'}

# %%
# in California
#golden16 = agencies16[(agencies16['state_l'] == "California")]
#golden15 = agencies15[(agencies15['state_l'] == "California")]
#golden14 = agencies14[(agencies14['state_l'] == "California")]
#golden13 = agencies13[(agencies13['state_l'] == "California")]

# %%
#emdf.to_csv('./csv_data/rewritten-itlist.csv')

# %%
new = set.intersection(set(tristate16.company), set(emdf.company))
new
# Out:
# {'engine shop', 'factory 360', 'moderne communications'}

# %% [markdown]
# - - -
# # Ok, let's see if I can iterate across multiple dataframes
# ### can't fight this feeling there is a smarter way to search for
# ### intersections, but I don't know what it is
# - - -

# %% [markdown]
# ## 1. first, a simple 'search for value' function
# #### across multiple dataframes, arguments passed in as a set

# %%
def searchAgency(sets,searchterm):
    for s in sets:
        print (s[s['company']==searchterm])

# %%
sf = [bayarea16, bayarea15, bayarea14, bayarea13]

# %%
len(sf)
# Out:
# 4

# %%
sf[1]
# Out:
#       unnamed: 0           city     state_l          metro   revenue  \
# 5              5      San Mateo  California  San Francisco  32945188
# 171          171  San Francisco  California  San Francisco   4943130
# 206          206  San Francisco  California  San Francisco  15163156
# 429          429  San Francisco  California  San Francisco   4349286
# 459          459   Corte Madera  California  San Francisco   4348829
# 675          675  SAN FRANCISCO  California  San Francisco  13906980
# 855          855        Hayward  California  San Francisco   9212755
# 1096        1096     Emeryville  California  San Francisco  19746744
# 1381        1381      San Mateo  California  San Francisco  15732367
# 1639        1639  San Francisco  California  San Francisco   3286837
# 1694        1694   Corte Madera  California  San Francisco  10276453
# 2210        2210  San Francisco  California  San Francisco   8208694
# 2951        2951  San Francisco  California  San Francisco  25916084
# ...

# %%
searchAgency(sf,'manifold')
# Out:
#       unnamed: 0           city     state_l          metro   revenue  \
# 3183        3183  San Francisco  California  San Francisco  14863448
#
#            url                 industry  workers  rank     id  yrs_on_list  \
# 3183  manifold  Advertising & Marketing       16  3183  44172            1
#
#         growth  ifmid  ifiid state_s   company
# 3183  105.7138      4      5      CA  manifold
# Empty DataFrame
# Columns: [unnamed: 0, city, state_l, metro, revenue, url, industry, workers, rank, id, yrs_on_list, growth, state_s, company]
# Index: []
# Empty DataFrame
# Columns: [unnamed: 0, city, state_l, metro, revenue, url, industry, workers, rank, id, yrs_on_list, growth, ifmid, ifiid, state_s, company]
# Index: []
# Empty DataFrame
# Columns: [unnamed: 0, city, state_l, metro, revenue, url, industry, workers, rank, id, yrs_on_list, growth, ifmid, ifiid, state_s, company]
# Index: []

# %%
searchAgency(sf,'bizo')
# Out:
# Empty DataFrame
# Columns: [unnamed: 0, city, state_l, metro, revenue, url, industry, workers, rank, id, yrs_on_list, growth, ifmid, ifiid, state_s, company]
# Index: []
# Empty DataFrame
# Columns: [unnamed: 0, city, state_l, metro, revenue, url, industry, workers, rank, id, yrs_on_list, growth, state_s, company]
# Index: []
#      unnamed: 0           city     state_l          metro   revenue   url  \
# 965         965  San Francisco  California  San Francisco  37100289  bizo
#
#                     industry  workers  rank     id  yrs_on_list    growth  \
# 965  Advertising & Marketing      133   968  21035            3  465.0702
#
#      ifmid  ifiid state_s company
# 965      4      5      CA    bizo
#      unnamed: 0           city     state_l          metro   revenue   url  \
# 546         546  San Francisco  California  San Francisco  22103529  bizo
#
#                     industry  workers  rank     id  yrs_on_list    growth  \
# ...

# %% [markdown]
# ## 2. next, a 'match value across dataframes' function
# #### across multiple dataframes, arguments passed in as a set
# #### against a single dataframe (column), also an argument

# %%
#common = set.intersection(set(bayarea16.company), set(emdf.company))
def matchAgency(sets,comparator):
    for s in sets:
#         print (s.name)
        matches = set.intersection(set(s.company), set(comparator.company))
        print (matches)

# %%
matchAgency(sf,emdf)
# Out:
# {'manifold'}
# set()
# set()
# set()

# %%
nyc = [tristate16,tristate15,tristate14,tristate13]

# %%
matchAgency(nyc,emdf)
# Out:
# {'factory 360', 'moderne communications', 'engine shop'}
# {'factory 360'}
# {'factory 360', 'engine shop'}
# {'mkg', 'invnt'}
