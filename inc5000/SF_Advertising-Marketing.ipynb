# %%
# Just a basic configuration
import pandas as pd

# %%
sixteen='/Users/xavier/Documents/src/dataviz/inc5000/csv_data/2016_inc5k.csv'
fifteen='/Users/xavier/Documents/src/dataviz/inc5000/csv_data/2015_inc5k.csv'
fourteen='/Users/xavier/Documents/src/dataviz/inc5000/csv_data/2014_inc5k.csv'
thirteen='/Users/xavier/Documents/src/dataviz/inc5000/csv_data/2013_inc5k.csv'
df16 = pd.read_csv(sixteen).rename(columns=str.lower)
df16['company'] = df16['company'].str.lower()
df15 = pd.read_csv(fifteen).rename(columns=str.lower)
df15['company'] = df15['company'].str.lower()
df14 = pd.read_csv(fourteen).rename(columns=str.lower)
df14['company'] = df14['company'].str.lower()
df13 = pd.read_csv(thirteen).rename(columns=str.lower)
df13['company'] = df13['company'].str.lower()
df13
# Out:
#       unnamed: 0               city               state_l  \
# 0              0         El Segundo            California
# 1              1           Dumfries              Virginia
# 2              2       Jacksonville               Florida
# 3              3         Carrollton                 Texas
# 4              4             Boston         Massachusetts
# 5              5             Austin                 Texas
# 6              6          Nashville             Tennessee
# 7              7      San Francisco            California
# 8              8          Bluffdale                  Utah
# 9              9            Warwick          Rhode Island
# 10            10             Vienna              Virginia
# 11            11      San Francisco            California
# 12            12            Orlando               Florida
# 13            13         Charleston        South Carolina
# 14            14         Washington  District of Columbia
# 15            15              Chino            California
# 16            16           Sarasota               Florida
# 17            17           Columbus                  Ohio
# 18            18          Cupertino            California
# 19            19            Seattle            Washington
# 20            20             Austin                 Texas
# 21            21             Dallas                 Texas
# 22            22           Portland                 Maine
# 23            23             Frisco                 Texas
# 24            24           New York              New York
# 25            25            Boulder              Colorado
# 26            26            Orlando               Florida
# 27            27             Irving                 Texas
# 28            28           New York              New York
# 29            29            Atlanta               Georgia
# ...          ...                ...                   ...
# 4945        4945     Southern Pines        North Carolina
# 4946        4946            Taunton         Massachusetts
# 4947        4947              Tampa               Florida
# 4948        4948      Oklahoma City              Oklahoma
# 4949        4949            Houston                 Texas
# 4950        4950             Tucson               Arizona
# 4951        4951              Burke              Virginia
# 4952        4952             McLean              Virginia
# 4953        4953      Winston-Salem        North Carolina
# 4954        4954          Hauppauge              New York
# 4955        4955           Lakewood              Colorado
# 4956        4956             Boston         Massachusetts
# 4957        4957            Rocklin            California
# 4958        4958               Mars          Pennsylvania
# 4959        4959      Tysons Corner              Virginia
# 4960        4960              Plano                 Texas
# 4961        4961          Englewood              Colorado
# 4962        4962            Moraine                  Ohio
# 4963        4963         Charleston        South Carolina
# 4964        4964          Livermore            California
# 4965        4965          Middleton         Massachusetts
# 4966        4966  North Little Rock              Arkansas
# 4967        4967      Downers Grove              Illinois
# 4968        4968       Dakota Dunes          South Dakota
# 4969        4969           Montvale            New Jersey
# 4970        4970       Mt. Sterling              Illinois
# 4971        4971         Wellington               Florida
# 4972        4972             Mebane        North Carolina
# 4973        4973          Kimberton          Pennsylvania
# 4974        4974           Bellevue            Washington
#
#                                          metro     revenue  \
# 0                                  Los Angeles   117872000
# 1                               Washington, DC    49625829
# 2                             Jacksonville, FL    25501186
# 3                                       Dallas  1919062000
# 4                                       Boston    87036000
# 5                                       Austin    45683484
# 6                            CBSA Metro Region    25489171
# 7                                San Francisco    23858231
# 8                               Salt Lake City    33104308
# 9     Providence-New Bedford-Fall River, RI-MA    18636055
# 10                              Washington, DC    29616593
# 11                               San Francisco    34121000
# 12                                 Orlando, FL    17042525
# 13             Charleston-North Charleston, SC    21138888
# 14                              Washington, DC   536000000
# 15        Riverside-San Bernardino-Ontario, CA    14295000
# 16               Sarasota-Bradenton-Venice, FL    11076624
# 17                                Columbus, OH    11775633
# 18                                    San Jose    26799334
# 19                                     Seattle     9628535
# 20                                      Austin     9770645
# 21                                      Dallas    76981000
# 22                 Portland-South Portland, ME    14629177
# 23                                      Dallas    13785928
# 24                               New York City    13740852
# 25                                 Boulder, CO    12555504
# 26                                 Orlando, FL    51118355
# 27                                      Dallas    23478000
# 28                               New York City     8066424
# 29                                     Atlanta     8039700
# ...                                        ...         ...
# 4945              Southern Pines-Pinehurst, NC    61334413
# 4946  Providence-New Bedford-Fall River, RI-MA     5209454
# 4947                                     Tampa    23581000
# 4948                         Oklahoma City, OK     4634455
# 4949                                   Houston    45552039
# 4950                                Tucson, AZ    81601287
# 4951                            Washington, DC     8678866
# 4952                            Washington, DC    25953273
# 4953                         Winston-Salem, NC     5109775
# 4954                             New York City    57324295
# 4955                                    Denver     4144441
# 4956                                    Boston    58707280
# 4957   Sacramento--Arden-Arcade--Roseville, CA    21044000
# 4958                            Pittsburgh, PA    38409224
# 4959                            Washington, DC    19476572
# 4960                                    Denver    42469720
# 4961                                    Denver    21381632
# 4962                                Dayton, OH   130744000
# 4963           Charleston-North Charleston, SC     8748231
# 4964                             San Francisco    10740186
# 4965                                    Boston     7445497
# 4966  Little Rock-North Little Rock-Conway, AR     2019218
# 4967                                   Chicago     7167015
# 4968                      Sioux City, IA-NE-SD   166032779
# 4969                             New York City    13445156
# 4970                                 Nashville  4527289905
# 4971                                     Miami     6813166
# 4972                            Burlington, NC    32621742
# 4973                              Philadelphia     4710000
# 4974                                   Seattle     6815293
#
#                                             url                      industry  \
# 0                                          fuhu  Consumer Products & Services
# 1                          federalconferencecom           Government Services
# 2                                 the-hci-group                        Health
# 3                                       bridger                        Energy
# 4                                        dataxu       Advertising & Marketing
# 5                  milestone-community-builders                   Real Estate
# 6                         value-payment-systems            Financial Services
# 7                          emerge-digital-group       Advertising & Marketing
# 8                                     goal-zero  Consumer Products & Services
# 9                                      yagoozon                        Retail
# 10                                       obxtek           Government Services
# 11                                       adroll       Advertising & Marketing
# 12                                   ubreakifix                        Retail
# 13                                        sparc                      Software
# 14                                 livingsocial  Consumer Products & Services
# 15                               amped-wireless             Computer Hardware
# 16                            integrity-funding            Financial Services
# 17                         vertex-body-sciences               Food & Beverage
# 18                                      bluekai       Advertising & Marketing
# 19                                     level-11                   IT Services
# 20                   patient-conversation-media                        Health
# 21                  wingspan-portfolio-advisors            Financial Services
# 22                            vets-first-choice                        Health
# 23                                   timberhorn                   IT Services
# 24                                 beenverified  Consumer Products & Services
# 25                                        trada       Advertising & Marketing
# 26                                         kony                      Software
# 27                            onesource-virtual  Business Products & Services
# 28                                     sailthru       Advertising & Marketing
# 29                                     innovolt  Business Products & Services
# ...                                         ...                           ...
# 4945                          trident-marketing       Advertising & Marketing
# 4946                    hs-brands-international  Business Products & Services
# 4947                           pilgrim-software                      Software
# 4948                       impressions-printing                 Manufacturing
# 4949                                   datacert                      Software
# 4950                           buffalo-exchange                        Retail
# 4951          sun-design-remodeling-specialists                  Construction
# 4952                      trowbridge-trowbridge           Government Services
# 4953                      frank-myers-auto-maxx  Consumer Products & Services
# 4954  smartsource-computer-audio-visual-rentals  Business Products & Services
# 4955                              hpc-solutions           Government Services
# 4956                baystate-financial-services            Financial Services
# 4957                                cell-marque                        Health
# 4958                          celtic-healthcare                        Health
# 4959                                 neosystems            Financial Services
# 4960                temporary-housing-directory          Travel & Hospitality
# 4961                         red-book-solutions  Business Products & Services
# 4962                                     lastar                 Manufacturing
# 4963                              urban-nirvana          Travel & Hospitality
# 4964                             cablewholesale             Computer Hardware
# 4965                    salem-metal-fabricators                 Manufacturing
# 4966                             the-pi-company  Business Products & Services
# 4967                               rfb-holdings               Human Resources
# 4968                         sterling-computers           Government Services
# 4969                                      csubs  Business Products & Services
# 4970                                  dot-foods               Food & Beverage
# 4971                         lethal-performance                        Retail
# 4972                           arcatech-systems            Financial Services
# 4973                                       all4        Environmental Services
# 4974                                        ine                     Education
#
#       workers  rank     id  yrs_on_list      growth  ifmid  ifiid state_s  \
# 0         143     1  22890            1  42148.0287      2      4      CA
# 1          51     2  20989            2  24830.5869      3      7      VA
# 2         113     3  22892            1  24544.7799     64     10      FL
# 3          50     4  22893            1  23308.1822      8     16      TX
# 4         220     5  22894            1  21337.4384      6      5      MA
# 5          63     6  22895            1  17937.7485     18      3      TX
# 6          27     7  22896            1  17404.1348    977      2      TN
# 7          75     8  22897            1  17064.0715      4      5      CA
# 8          97     9  22898            1  16980.5405     12      4      UT
# 9          15    10  21148            2  16689.2387     55     18      RI
# 10        149    11  20997            2  16433.2059      3      7      VA
# 11        200    12  20974            2  15064.8889      4      5      CA
# 12        180    13  22899            1  14102.1042     68     18      FL
# 13        160    14  22900            1  12862.5195    536      9      SC
# 14       4100    15  22901            1  12333.1688      3      4      DC
# 15         26    16  22902            1  11067.9688     54     25      CA
# 16         11    18  20972            2  10462.1421    576      2      FL
# 17         51    19  22904            1  10010.3562     19     11      OH
# 18        107    20  22905            1   9245.4970     20      5      CA
# 19         30    21  22906            1   9043.9079     23      8      WA
# 20         59    22  21096            2   8782.4045     18     10      TX
# 21       1704    23  22821            1   8768.7788      8      2      TX
# 22         74    24  20992            2   8585.3030   1018     10      ME
# 23        175    25  22858            1   8516.2050      8      8      TX
# 24         17    26  22907            1   8442.6497      9      4      NY
# 25         75    27  22908            1   8100.9053     31      5      CO
# 26       1100    28  22909            1   7786.2497     68      9      FL
# 27        260    29  22910            1   7353.3333      8     17      TX
# 28         79    30  22911            1   7322.1789      9      5      NY
# 29         30    31  22912            1   7247.6942     29     17      GA
# ...       ...   ...    ...          ...         ...    ...    ...     ...
# 4945      487  4972   2310            5     35.1518    152      5      NC
# 4946       26  4973  20794            3     35.1349     55     17      MA
# 4947      126  4974   7262            5     35.0805      7      9      FL
# 4948       49  4975   4258            6     35.0671     38     15      OK
# 4949      252  4976   6205            9     35.0285     22      9      TX
# 4950      756  4977   7455            6     34.9787    154     18      AZ
# 4951       52  4978   4122            4     34.9526      3     20      VA
# 4952      224  4979  19503            3     34.9108      3      7      VA
# 4953       35  4980  22430            2     34.9086    245      4      NC
# 4954      296  4981  24586            1     34.8994      9     17      NY
# 4955       18  4982  21661            3     34.8780     30      7      CO
# 4956      335  4983   4199            5     34.8762      6      2      MA
# 4957       72  4984  20373            3     34.8542     75     10      CA
# 4958      498  4985  24587            1     34.8385     52     10      PA
# 4959      108  4986  18479            4     34.7837      3      2      VA
# 4960       50  4987   2371            6     34.7626     30     22      TX
# 4961      105  4988  19194            2     34.7619     30     17      CO
# 4962      511  4989  18661            4     34.7404     39     15      OH
# 4963      220  4990   4132            4     34.6844    536     22      SC
# 4964       27  4991  24588            1     34.6595      4     25      CA
# 4965       50  4992  24589            1     34.6513      6     15      MA
# 4966        6  4993  24590            1     34.6300    122     17      AR
# 4967       27  4994   4266            4     34.5593     17     21      IL
# 4968       98  4995  20270            3     34.5594    709      7      SD
# 4969       19  4996   1492            6     34.4437      9     17      NJ
# 4970     3919  4997  24591            1     34.3834     82     11      IL
# 4971        8  4998  24592            1     34.3256      1     18      FL
# 4972       63  4999   1197            6     34.2575    170      2      NC
# 4973       34  5000   3829            6     34.2263     49     23      PA
# 4974       35  5000      4            3     34.2289     23     19      WA
#
#                                           company
# 0                                            fuhu
# 1                           federalconference.com
# 2                                   the hci group
# 3                                         bridger
# 4                                          dataxu
# 5                    milestone community builders
# 6                           value payment systems
# 7                            emerge digital group
# 8                                       goal zero
# 9                                        yagoozon
# 10                                         obxtek
# 11                                         adroll
# 12                                     ubreakifix
# 13                                          sparc
# 14                                   livingsocial
# 15                                 amped wireless
# 16                              integrity funding
# 17                           vertex body sciences
# 18                                        bluekai
# 19                                       level 11
# 20                     patient conversation media
# 21                    wingspan portfolio advisors
# 22                              vets first choice
# 23                                     timberhorn
# 24                                   beenverified
# 25                                          trada
# 26                                           kony
# 27                              onesource virtual
# 28                                       sailthru
# 29                                       innovolt
# ...                                           ...
# 4945                            trident marketing
# 4946                      hs brands international
# 4947                             pilgrim software
# 4948                         impressions printing
# 4949                                     datacert
# 4950                             buffalo exchange
# 4951            sun design remodeling specialists
# 4952                      trowbridge & trowbridge
# 4953                        frank myers auto maxx
# 4954  smartsource computer & audio visual rentals
# 4955                                hpc solutions
# 4956                  baystate financial services
# 4957                                  cell marque
# 4958                            celtic healthcare
# 4959                                   neosystems
# 4960                  temporary housing directory
# 4961                           red book solutions
# 4962                                       lastar
# 4963                                urban nirvana
# 4964                               cablewholesale
# 4965                      salem metal fabricators
# 4966                               the pi company
# 4967                                 rfb holdings
# 4968                           sterling computers
# 4969                                        csubs
# 4970                                    dot foods
# 4971                           lethal performance
# 4972                             arcatech systems
# 4973                                         all4
# 4974                                          ine
#
# [4975 rows x 16 columns]

# %%
eventmarketer='./csv_data/it-list.csv'
# raw='/Users/ganesha/Documents/src/dataviz/inc5000/csv_data/it-list.txt'
emdf = pd.read_csv(eventmarketer).rename(columns=str.lower)
emdf['company'] = emdf['company'].str.lower()
emdf
# Out:
#     index                                               tags  \
# 0       0  all guerrilla-street-programs mobile-tours spo...
# 1       1  all b-to-b-meetingsevents mobile-tours sponsor...
# 2       2  all b-to-b-meetingsevents internal-employee-ev...
# 3       3  all buzz-influencer-programs mobile-tours spon...
# 4       4          all mobile-tours pr-events pop-up-stores
# 5       5        all launch-events mobile-tours trade-shows
# 6       6  all b-to-b-meetingsevents launch-events sales-...
# 7       7  all buzz-influencer-programs launch-events spo...
# 8       8  all guerrilla-street-programs mobile-tours spo...
# 9       9               all mobile-tours pr-events sampling
# 10     10  all b-to-b-meetingsevents internal-employee-ev...
# 11     11  all buzz-influencer-programs launch-events pop...
# 12     12  all retailtainment-events multicultural-events...
# 13     13  all b-to-b-meetingsevents internal-employee-ev...
# 14     14  all buzz-influencer-programs guerrilla-street-...
# 15     15  all automotive-launches-and-personal-drive-exp...
# 16     16  all mobile-tours multicultural-events sponsors...
# 17     17  all guerrilla-street-programs mobile-tours sam...
# 18     18  all mobile-tours sampling sponsorship-activation
# 19     19  all buzz-influencer-programs mobile-tours spon...
# 20     20  all b-to-b-meetingsevents mobile-tours nightli...
# 21     21  all b-to-b-meetingsevents launch-events worldw...
# 22     22  all b-to-b-meetingsevents launch-events pr-eve...
# 23     23  all mobile-tours sponsorship-activation trade-...
# 24     24           all launch-events mobile-tours sampling
# 25     25  all b-to-b-meetingsevents launch-events worldw...
# 26     26  all pop-up-stores sampling sponsorship-activat...
# 27     27  all buzz-influencer-programs pr-events sponsor...
# 28     28  all b-to-b-meetingsevents internal-employee-ev...
# 29     29  all college-campus-marketing guerrilla-street-...
# ..    ...                                                ...
# 70     70  all guerrilla-street-programs launch-events ni...
# 71     71  all college-campus-marketing events-for-conten...
# 72     72  all b-to-b-meetingsevents sales-conferencesmee...
# 73     73  all b-to-b-meetingsevents launch-events press-...
# 74     74  all retailtainment-events launch-events sponso...
# 75     75  all college-campus-marketing mobile-tours samp...
# 76     76  all mobile-tours sampling sponsorship-activation
# 77     77  all buzz-influencer-programs developer-confere...
# 78     78  all mobile-tours sponsorship-activation worldw...
# 79     79  all b-to-b-meetingsevents mobile-tours sponsor...
# 80     80  all b-to-b-meetingsevents sponsorship-activati...
# 81     81  all b-to-b-meetingsevents sampling sponsorship...
# 82     82  all guerrilla-street-programs mobile-tours spo...
# 83     83  all launch-events pr-events sponsorship-activa...
# 84     84  all b-to-b-meetingsevents internal-employee-ev...
# 85     85  all mobile-tours sampling sponsorship-activation
# 86     86  all b-to-b-meetingsevents buzz-influencer-prog...
# 87     87  all mobile-tours sponsorship-activation sports...
# 88     88  all retailtainment-events launch-events pop-up...
# 89     89  all buzz-influencer-programs mobile-tours nigh...
# 90     90  all b-to-b-meetingsevents developer-conference...
# 91     91  all buzz-influencer-programs sponsorship-activ...
# 92     92  all b-to-b-meetingsevents mobile-tours sponsor...
# 93     93  all mobile-tours pr-events sponsorship-activat...
# 94     94  all b-to-b-meetingsevents developer-conference...
# 95     95  all b-to-b-meetingsevents internal-employee-ev...
# 96     96  all buzz-influencer-programs pr-events sponsor...
# 97     97  all retailtainment-events launch-events pr-eve...
# 98     98  all b-to-b-meetingsevents buzz-influencer-prog...
# 99     99  all pr-events sponsorship-activation worldwide...
#
#                                                   url  \
# 0    http://www.eventmarketer.com/company/activent...
# 1    http://www.eventmarketer.com/company/advantag...
# 2      http://www.eventmarketer.com/company/agencyea/
# 3    http://www.eventmarketer.com/company/all-terr...
# 4    http://www.eventmarketer.com/company/allied-e...
# 5    http://www.eventmarketer.com/company/astound-...
# 6    http://www.eventmarketer.com/company/barkley-...
# 7     http://www.eventmarketer.com/company/bmf-media/
# 8    http://www.eventmarketer.com/company/bolt-mar...
# 9    http://www.eventmarketer.com/company/bottlero...
# 10   http://www.eventmarketer.com/company/broadstr...
# 11    http://www.eventmarketer.com/company/c3-agency/
# 12   http://www.eventmarketer.com/company/cardenas...
# 13       http://www.eventmarketer.com/company/cramer/
# 14   http://www.eventmarketer.com/company/division...
# 15    http://www.eventmarketer.com/company/driveshop/
# 16   http://www.eventmarketer.com/company/elemento...
# 17    http://www.eventmarketer.com/company/elite-exp/
# 18         http://www.eventmarketer.com/company/emg3/
# 19   http://www.eventmarketer.com/company/engine-s...
# 20      http://www.eventmarketer.com/company/epsilon/
# 21   http://www.eventmarketer.com/company/event-st...
# 22     http://www.eventmarketer.com/company/eventage/
# 23   http://www.eventmarketer.com/company/eventive...
# 24    http://www.eventmarketer.com/company/eventnext/
# 25   http://www.eventmarketer.com/company/executiv...
# 26   http://www.eventmarketer.com/company/factory-...
# 27         http://www.eventmarketer.com/company/fcbx/
# 28   http://www.eventmarketer.com/company/first-pr...
# 29       http://www.eventmarketer.com/company/fluent/
# ..                                                ...
# 70       http://www.eventmarketer.com/company/mosaic/
# 71       http://www.eventmarketer.com/company/motive/
# 72   http://www.eventmarketer.com/company/mvp-coll...
# 73   http://www.eventmarketer.com/company/na-colle...
# 74   http://www.eventmarketer.com/company/ncompass...
# 75   http://www.eventmarketer.com/company/newbridg...
# 76   http://www.eventmarketer.com/company/next-mar...
# 77   http://www.eventmarketer.com/company/nve-expe...
# 78      http://www.eventmarketer.com/company/octagon/
# 79   http://www.eventmarketer.com/company/onboard-...
# 80   http://www.eventmarketer.com/company/opus-eve...
# 81   http://www.eventmarketer.com/company/performa...
# 82   http://www.eventmarketer.com/company/pgw-expe...
# 83     http://www.eventmarketer.com/company/pop2life/
# 84   http://www.eventmarketer.com/company/prosceni...
# 85   http://www.eventmarketer.com/company/redpeg-m...
# 86   http://www.eventmarketer.com/company/revel-gr...
# 87   http://www.eventmarketer.com/company/revolution/
# 88          http://www.eventmarketer.com/company/set/
# 89   http://www.eventmarketer.com/company/soho-exp...
# 90       http://www.eventmarketer.com/company/sparks/
# 91   http://www.eventmarketer.com/company/superfly...
# 92       http://www.eventmarketer.com/company/switch/
# 93   http://www.eventmarketer.com/company/synergy-...
# 94   http://www.eventmarketer.com/company/taylor-g...
# 95   http://www.eventmarketer.com/company/touch-wo...
# 96   http://www.eventmarketer.com/company/track-ma...
# 97   http://www.eventmarketer.com/company/united-e...
# 98   http://www.eventmarketer.com/company/visionar...
# 99    http://www.eventmarketer.com/company/wasserman/
#
#                          company
# 0             activent marketing
# 1        advantage international
# 2                       agencyea
# 3                    all terrain
# 4            allied experiential
# 5                  astound group
# 6          barkley kalpak agency
# 7                      bmf media
# 8           bolt marketing group
# 9         bottlerocket marketing
# 10                   broadstreet
# 11                     c3 agency
# 12    cardenas marketing network
# 13                        cramer
# 14                division black
# 15                     driveshop
# 16                   elemento l2
# 17         elite marketing group
# 18                          emg3
# 19                   engine shop
# 20                       epsilon
# 21          event strategy group
# 22                      eventage
# 23                      eventive
# 24                     eventnext
# 25        executive visions inc.
# 26                   factory 360
# 27                          fcbx
# 28                first protocol
# 29                        fluent
# ..                           ...
# 70                        mosaic
# 71                        motive
# 72             mvp collaborative
# 73                 na collective
# 74                      ncompass
# 75                newbridge live
# 76                next marketing
# 77                           nve
# 78                       octagon
# 79         on board experiential
# 80                   opus agency
# 81   performance marketing group
# 82                pgw experience
# 83                      pop2life
# 84                    proscenium
# 85              redpeg marketing
# 86                         revel
# 87                    revolution
# 88                           set
# 89             soho experiential
# 90                        sparks
# 91                      superfly
# 92                        switch
# 93                       synergy
# 94              the taylor group
# 95               touch worldwide
# 96         track marketing group
# 97    united entertainment group
# 98           the visionary group
# 99                     wasserman
#
# [100 rows x 4 columns]

# %%
# affordable
radar16 = df16[(df16['revenue'].astype('int') > 999999) & (df16['revenue'].astype('int') < 39999999)]
radar15 = df15[(df15['revenue'].astype('int') > 999999) & (df15['revenue'].astype('int') < 39999999)]
radar14 = df14[(df14['revenue'].astype('int') > 999999) & (df14['revenue'].astype('int') < 39999999)]
radar13 = df13[(df13['revenue'].astype('int') > 999999) & (df13['revenue'].astype('int') < 39999999)]

# %%
# advertising and marketing
agencies16 = radar16[(radar16['industry'] == "Advertising & Marketing")]
agencies15 = radar15[(radar15['industry'] == "Advertising & Marketing")]
agencies14 = radar14[(radar14['industry'] == "Advertising & Marketing")]
agencies13 = radar13[(radar13['industry'] == "Advertising & Marketing")]

# %%
sf = agencies16[(agencies16['city'] == "San Francisco")]
sf.count()
# Out:
# unnamed: 0     10
# city           10
# state_l        10
# metro          10
# revenue        10
# url            10
# industry       10
# workers        10
# rank           10
# id             10
# yrs_on_list    10
# growth         10
# ifmid          10
# ifiid          10
# state_s        10
# company        10
# dtype: int64

# %%
sf = agencies16[(agencies16['metro'] == "San Francisco")]
sf.count()
# Out:
# unnamed: 0     17
# city           17
# state_l        17
# metro          17
# revenue        17
# url            17
# industry       17
# workers        17
# rank           17
# id             17
# yrs_on_list    17
# growth         17
# ifmid          17
# ifiid          17
# state_s        17
# company        17
# dtype: int64

# %%
ny16 = agencies16[(agencies16['metro'] == "New York City")]
ny16.count()
# Out:
# unnamed: 0     40
# city           40
# state_l        40
# metro          40
# revenue        40
# url            40
# industry       40
# workers        40
# rank           40
# id             40
# yrs_on_list    40
# growth         40
# ifmid          40
# ifiid          40
# state_s        40
# company        40
# dtype: int64

# %% [markdown]
# - - -
# > Ok—there are more in the metro of SF than in the city, so let's start there...

# %%
# in California
golden16 = agencies16[(agencies16['metro'] == "San Francisco")]
golden15 = agencies15[(agencies15['metro'] == "San Francisco")]
golden14 = agencies14[(agencies14['metro'] == "San Francisco")]
golden13 = agencies13[(agencies13['metro'] == "San Francisco")]

# %%
golden16
# Out:
#       unnamed: 0           city     state_l          metro   revenue  \
# 291          291  San Francisco  California  San Francisco  10259310
# 539          539   Redwood City  California  San Francisco   7896206
# 716          716  San Francisco  California  San Francisco  16837733
# 900          900     Emeryville  California  San Francisco  22856865
# 1114        1114        Hayward  California  San Francisco  12015089
# 1493        1493      San Ramon  California  San Francisco   5842000
# 1588        1588   Corte Madera  California  San Francisco   5252671
# 1703        1703  San Francisco  California  San Francisco   4473327
# 1769        1769  San Francisco  California  San Francisco   5135905
# 2183        2183  San Francisco  California  San Francisco  10994175
# 2867        2867  San Francisco  California  San Francisco   5896311
# 3088        3088   Corte Madera  California  San Francisco  13363428
# 3103        3103     Emeryville  California  San Francisco   4658366
# 3183        3183  San Francisco  California  San Francisco  14863448
# 4003        4003  San Francisco  California  San Francisco  16221086
# 4012        4012  San Francisco  California  San Francisco  29321751
# 4054        4054  San Francisco  California  San Francisco  11216000
#
#                             url                 industry  workers  rank  \
# 291                 metamarkets  Advertising & Marketing       36   292
# 539             pierry-software  Advertising & Marketing       50   538
# 716       muh-tay-zik-|-hof-fer  Advertising & Marketing       80   715
# 900                  sellpoints  Advertising & Marketing       62   899
# 1114                   corefact  Advertising & Marketing       50  1114
# 1493               clever-girls  Advertising & Marketing       29  1493
# 1588                 sway-group  Advertising & Marketing       36  1588
# 1703             levitate-media  Advertising & Marketing       22  1704
# 1769         boca-communcations  Advertising & Marketing       37  1770
# 2183  highwire-public-relations  Advertising & Marketing       55  2184
# 2867            six-spoke-media  Advertising & Marketing        7  2867
# 3088   mogo-marketing-and-media  Advertising & Marketing       40  3088
# 3103       bhava-communications  Advertising & Marketing       27  3103
# 3183                   manifold  Advertising & Marketing       16  3183
# 4003                launchsquad  Advertising & Marketing      108  4002
# 4012                  dwa-media  Advertising & Marketing       39  4011
# 4054                   eastwick  Advertising & Marketing       55  4053
#
#          id  yrs_on_list     growth  ifmid  ifiid state_s  \
# 291   43169            1  1350.9159      4      5      CA
# 539   43304            1   716.3174      4      5      CA
# 716   43388            1   549.4458      4      5      CA
# 900   37269            2   445.6723      4      5      CA
# 1114  37162            2   347.5897      4      5      CA
# 1493  43684            1   255.7856      4      5      CA
# 1588  36956            2   237.6187      4      5      CA
# 1703  26109            3   218.1990      4      5      CA
# 1769  37488            2   210.9500      4      5      CA
# 2183  23516            4   168.5872      4      5      CA
# 2867  24990            3   120.9404      4      5      CA
# 3088  37506            2   110.0348      4      5      CA
# 3103  26443            3   109.5256      4      5      CA
# 3183  44172            1   105.7138      4      5      CA
# 4003   1186            9    72.7996      4      5      CA
# 4012  25312            3    72.5915      4      5      CA
# 4054  38219            2    71.0017      4      5      CA
#
#                         company
# 291                 metamarkets
# 539             pierry software
# 716       muh-tay-zik | hof-fer
# 900                  sellpoints
# 1114                   corefact
# 1493               clever girls
# 1588                 sway group
# 1703             levitate media
# 1769         boca communcations
# 2183  highwire public relations
# 2867            six spoke media
# 3088   mogo marketing and media
# 3103       bhava communications
# 3183                   manifold
# 4003                launchsquad
# 4012                  dwa media
# 4054                   eastwick

# %%
emdf.loc[:68]
# Out:
#     index                                               tags  \
# 0       0  all guerrilla-street-programs mobile-tours spo...
# 1       1  all b-to-b-meetingsevents mobile-tours sponsor...
# 2       2  all b-to-b-meetingsevents internal-employee-ev...
# 3       3  all buzz-influencer-programs mobile-tours spon...
# 4       4          all mobile-tours pr-events pop-up-stores
# 5       5        all launch-events mobile-tours trade-shows
# 6       6  all b-to-b-meetingsevents launch-events sales-...
# 7       7  all buzz-influencer-programs launch-events spo...
# 8       8  all guerrilla-street-programs mobile-tours spo...
# 9       9               all mobile-tours pr-events sampling
# 10     10  all b-to-b-meetingsevents internal-employee-ev...
# 11     11  all buzz-influencer-programs launch-events pop...
# 12     12  all retailtainment-events multicultural-events...
# 13     13  all b-to-b-meetingsevents internal-employee-ev...
# 14     14  all buzz-influencer-programs guerrilla-street-...
# 15     15  all automotive-launches-and-personal-drive-exp...
# 16     16  all mobile-tours multicultural-events sponsors...
# 17     17  all guerrilla-street-programs mobile-tours sam...
# 18     18  all mobile-tours sampling sponsorship-activation
# 19     19  all buzz-influencer-programs mobile-tours spon...
# 20     20  all b-to-b-meetingsevents mobile-tours nightli...
# 21     21  all b-to-b-meetingsevents launch-events worldw...
# 22     22  all b-to-b-meetingsevents launch-events pr-eve...
# 23     23  all mobile-tours sponsorship-activation trade-...
# 24     24           all launch-events mobile-tours sampling
# 25     25  all b-to-b-meetingsevents launch-events worldw...
# 26     26  all pop-up-stores sampling sponsorship-activat...
# 27     27  all buzz-influencer-programs pr-events sponsor...
# 28     28  all b-to-b-meetingsevents internal-employee-ev...
# 29     29  all college-campus-marketing guerrilla-street-...
# ..    ...                                                ...
# 39     39  all mobile-tours sampling sponsorship-activation
# 40     40            all b-to-b-meetingsevents press-events
# 41     41  all mobile-tours sponsorship-activation worldw...
# 42     42             all b-to-b-meetingsevents trade-shows
# 43     43  all college-campus-marketing mobile-tours spon...
# 44     44  all launch-events mobile-tours sponsorship-act...
# 45     45  all b-to-b-meetingsevents incentive-travel spo...
# 46     46  all mobile-tours nightlife-marketing pop-up-st...
# 47     47  all b-to-b-meetingsevents internal-employee-ev...
# 48     48  all b-to-b-meetingsevents pr-events worldwide-...
# 49     49  all b-to-b-meetingsevents launch-events sponso...
# 50     50  all b-to-b-meetingsevents developer-conference...
# 51     51  all b-to-b-meetingsevents buzz-influencer-prog...
# 52     52  all corporate-visitorexperience-centers trade-...
# 53     53  all buzz-influencer-programs mobile-tours nigh...
# 54     54  all b-to-b-meetingsevents sales-conferencesmee...
# 55     55  all b-to-b-meetingsevents buzz-influencer-prog...
# 56     56  all b-to-b-meetingsevents launch-events pr-eve...
# 57     57  all internal-employee-events launch-events wor...
# 58     58  all buzz-influencer-programs developer-confere...
# 59     59  all college-campus-marketing mobile-tours spon...
# 60     60  all digitalsocial-program-creation internal-em...
# 61     61  all guerrilla-street-programs mobile-tours spo...
# 62     62  all automotive-launches-and-personal-drive-exp...
# 63     63  all b-to-b-meetingsevents mobile-tours press-e...
# 64     64  all launch-events pr-events sponsorship-activa...
# 65     65  all buzz-influencer-programs launch-events spo...
# 66     66  all pr-events pop-up-stores sponsorship-activa...
# 67     67  all buzz-influencer-programs nightlife-marketi...
# 68     68  all guerrilla-street-programs pr-events pop-up...
#
#                                                   url  \
# 0    http://www.eventmarketer.com/company/activent...
# 1    http://www.eventmarketer.com/company/advantag...
# 2      http://www.eventmarketer.com/company/agencyea/
# 3    http://www.eventmarketer.com/company/all-terr...
# 4    http://www.eventmarketer.com/company/allied-e...
# 5    http://www.eventmarketer.com/company/astound-...
# 6    http://www.eventmarketer.com/company/barkley-...
# 7     http://www.eventmarketer.com/company/bmf-media/
# 8    http://www.eventmarketer.com/company/bolt-mar...
# 9    http://www.eventmarketer.com/company/bottlero...
# 10   http://www.eventmarketer.com/company/broadstr...
# 11    http://www.eventmarketer.com/company/c3-agency/
# 12   http://www.eventmarketer.com/company/cardenas...
# 13       http://www.eventmarketer.com/company/cramer/
# 14   http://www.eventmarketer.com/company/division...
# 15    http://www.eventmarketer.com/company/driveshop/
# 16   http://www.eventmarketer.com/company/elemento...
# 17    http://www.eventmarketer.com/company/elite-exp/
# 18         http://www.eventmarketer.com/company/emg3/
# 19   http://www.eventmarketer.com/company/engine-s...
# 20      http://www.eventmarketer.com/company/epsilon/
# 21   http://www.eventmarketer.com/company/event-st...
# 22     http://www.eventmarketer.com/company/eventage/
# 23   http://www.eventmarketer.com/company/eventive...
# 24    http://www.eventmarketer.com/company/eventnext/
# 25   http://www.eventmarketer.com/company/executiv...
# 26   http://www.eventmarketer.com/company/factory-...
# 27         http://www.eventmarketer.com/company/fcbx/
# 28   http://www.eventmarketer.com/company/first-pr...
# 29       http://www.eventmarketer.com/company/fluent/
# ..                                                ...
# 39   http://www.eventmarketer.com/company/havas-im...
# 40      http://www.eventmarketer.com/company/henry-v/
# 41     http://www.eventmarketer.com/company/ignition/
# 42   http://www.eventmarketer.com/company/imaginat...
# 43     http://www.eventmarketer.com/company/img-live/
# 44   http://www.eventmarketer.com/company/infinity...
# 45     http://www.eventmarketer.com/company/infrared/
# 46      http://www.eventmarketer.com/company/inspira/
# 47     http://www.eventmarketer.com/company/invision/
# 48        http://www.eventmarketer.com/company/invnt/
# 49   http://www.eventmarketer.com/company/jack-mor...
# 50   http://www.eventmarketer.com/company/kenwood-...
# 51   http://www.eventmarketer.com/company/kicking-...
# 52        http://www.eventmarketer.com/company/kubik/
# 53   http://www.eventmarketer.com/company/legacy-m...
# 54   http://www.eventmarketer.com/company/leo-events/
# 55   http://www.eventmarketer.com/company/mac-pres...
# 56   http://www.eventmarketer.com/company/magnetic...
# 57    http://www.eventmarketer.com/company/manifesto/
# 58     http://www.eventmarketer.com/company/manifold/
# 59   http://www.eventmarketer.com/company/marketin...
# 60   http://www.eventmarketer.com/company/marketin...
# 61   http://www.eventmarketer.com/company/marketin...
# 62   http://www.eventmarketer.com/company/match-ac...
# 63   http://www.eventmarketer.com/company/michael-...
# 64   http://www.eventmarketer.com/company/mirrorball/
# 65   http://www.eventmarketer.com/company/mirrored...
# 66          http://www.eventmarketer.com/company/mkg/
# 67     http://www.eventmarketer.com/company/mktg-inc/
# 68   http://www.eventmarketer.com/company/moderne-...
#
#                         company
# 0            activent marketing
# 1       advantage international
# 2                      agencyea
# 3                   all terrain
# 4           allied experiential
# 5                 astound group
# 6         barkley kalpak agency
# 7                     bmf media
# 8          bolt marketing group
# 9        bottlerocket marketing
# 10                  broadstreet
# 11                    c3 agency
# 12   cardenas marketing network
# 13                       cramer
# 14               division black
# 15                    driveshop
# 16                  elemento l2
# 17        elite marketing group
# 18                         emg3
# 19                  engine shop
# 20                      epsilon
# 21         event strategy group
# 22                     eventage
# 23                     eventive
# 24                    eventnext
# 25       executive visions inc.
# 26                  factory 360
# 27                         fcbx
# 28               first protocol
# 29                       fluent
# ..                          ...
# 39                 havas impact
# 40                      henry v
# 41                     ignition
# 42                  imagination
# 43                     img live
# 44      infinity marketing team
# 45                     infrared
# 46      inspira marketing group
# 47      invision communications
# 48                        invnt
# 49        jack morton worldwide
# 50          kenwood experiences
# 51                  kicking cow
# 52                        kubik
# 53             legacy marketing
# 54                   leo events
# 55                 mac presents
# 56       magnetic collaborative
# 57                    manifesto
# 58                     manifold
# 59            the marketing arm
# 60            marketing factory
# 61              marketing werks
# 62        match marketing group
# 63       the michael alan group
# 64                   mirrorball
# 65               mirrored media
# 66                          mkg
# 67                         mktg
# 68       moderne communications
#
# [69 rows x 4 columns]

# %%
# in California
tristate16 = agencies16[(agencies16['metro'] == "New York City")]
tristate15 = agencies15[(agencies15['metro'] == "New York City")]
tristate14 = agencies14[(agencies14['metro'] == "New York City")]
tristate13 = agencies13[(agencies13['metro'] == "New York City")]

# %%
ind = golden16.company.isin(emdf.company)
ind
# Out:
# 291     False
# 539     False
# 716     False
# 900     False
# 1114    False
# 1493    False
# 1588    False
# 1703    False
# 1769    False
# 2183    False
# 2867    False
# 3088    False
# 3103    False
# 3183    False
# 4003    False
# 4012    False
# 4054    False
# Name: company, dtype: bool

# %%
c
# Out:
# set()

# %%
common = set.intersection(set(golden16.company), set(emdf.company))
common
# Out:
# set()

# %%
common = set.intersection(set(tristate16.company), set(emdf.company))
common
# Out:
# set()

# %%
# in California
#golden16 = agencies16[(agencies16['state_l'] == "California")]
#golden15 = agencies15[(agencies15['state_l'] == "California")]
#golden14 = agencies14[(agencies14['state_l'] == "California")]
#golden13 = agencies13[(agencies13['state_l'] == "California")]
