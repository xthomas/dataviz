# %%
# %pylab inline
import os
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
root_dir = '../data/nyc-complaints-demo/'
requests = root_dir + '311-service-requests.csv'

# %%
serviceData = pd.read_csv(requests)
orig_data = pd.read_csv(requests, nrows=100000, parse_dates=['Created Date'])
small_data = pd.read_csv(requests, nrows=5)
# Out:
# /Users/ganesha/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1139: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
# /Users/ganesha/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1139: DtypeWarning: Columns (8,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
serviceData["Complaint Type"].value_counts()[:10].plot(kind='bar')
