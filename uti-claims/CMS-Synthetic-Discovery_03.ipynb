# %%
import pandas as pd
import numpy as np

# %%
# DE1_0_2008_Beneficiary_Summary_File_Sample_1.csv
# DE1_0_2008_to_2010_Carrier_Claims_Sample_1A.csv
# DE1_0_2008_to_2010_Carrier_Claims_Sample_1B.csv
# DE1_0_2008_to_2010_Inpatient_Claims_Sample_1.csv
# DE1_0_2008_to_2010_Outpatient_Claims_Sample_1.csv
# DE1_0_2008_to_2010_Prescription_Drug_Events_Sample_1.csv
# DE1_0_2009_Beneficiary_Summary_File_Sample_1.csv
# DE1_0_2010_Beneficiary_Summary_File_Sample_20.csv

# %%
datadir = '/home/xavier/data/cms_data/Data-Entrepreneurs-Synthetic-PUF/'
summaryFile = 'DE1_0_2008_Beneficiary_Summary_File_Sample_1.csv'
claimFile = 'DE1_0_2008_to_2010_Carrier_Claims_Sample_1A.csv'
drugFile = 'DE1_0_2008_to_2010_Prescription_Drug_Events_Sample_1.csv'

# %%
claims = pd.read_csv(datadir + drugFile)
# Out:
# /home/xavier/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
list(claims)
# Out:
# ['DESYNPUF_ID',
#  'PDE_ID',
#  'SRVC_DT',
#  'PROD_SRVC_ID',
#  'QTY_DSPNSD_NUM',
#  'DAYS_SUPLY_NUM',
#  'PTNT_PAY_AMT',
#  'TOT_RX_CST_AMT']

# %%
claims.head(15)
# Out:
#          DESYNPUF_ID           PDE_ID   SRVC_DT PROD_SRVC_ID  QTY_DSPNSD_NUM  \
# 0   00013D2EFD8E45D1  233664490397622  20080103    247037252            30.0
# 1   00013D2EFD8E45D1  233644490171972  20080105    223039502            10.0
# 2   00013D2EFD8E45D1  233974489116848  20080109    364724812           120.0
# 3   00013D2EFD8E45D1  233574491083209  20080123    179180672            30.0
# 4   00013D2EFD8E45D1  233024491180571  20080124  58016005300            30.0
# 5   00013D2EFD8E45D1  233884492803278  20080124  53650001801            30.0
# 6   00013D2EFD8E45D1  233594491623171  20080125      8032506           180.0
# 7   00013D2EFD8E45D1  233894491962732  20080129  58016081825           100.0
# 8   00013D2EFD8E45D1  233344491666810  20080201  51129143701            30.0
# 9   00013D2EFD8E45D1  233884490733605  20080205  67668013231            10.0
# 10  00013D2EFD8E45D1  233254492355736  20080214    254511335            60.0
# ...

# %%
icd = claims.loc[:,'DESYNPUF_ID':'ICD9_DGNS_CD_8']
icd.shape
# Out:
# (2370667, 12)

# %%
utibase = icd[
    icd['ICD9_DGNS_CD_1']
    .str.contains('599', case = False, na=False)]

# %%
utibase.shape
# Out:
# (7125, 12)

# %%
utibase
# Out:
#               DESYNPUF_ID           CLM_ID  CLM_FROM_DT  CLM_THRU_DT  \
# 8        00016F745862898F  887953385848149     20081020     20081020
# 413      0004F0ABD505251D  887593389474703     20091122     20091122
# 577      00052705243EA128  887323388671747     20100409     20100409
# 654      0007F12A492FD25D  887353385949566     20080620     20080620
# 1227     0011CB1FE23E91AF  887343385957126     20080730     20080803
# 1436     00139C345A104F72  887833387309417     20091105     20091105
# 1850     0018C6D3871BA1E8  887663388998553     20080530     20080530
# 2376     001EA2F4DB30F105  887843386072543     20091028     20091028
# 2406     001EA2F4DB30F105  887163387079761     20100920     20100920
# 2452     001F135A720283D1  887333388854561     20090130     20090130
# 2483     001F135A720283D1  887863389371691     20091111     20091111
# 2764     0021D4CDAFC0609F  887303386370784     20081028     20081028
# 2977     002354398A00234E  887223388791946     20091127     20091127
# ...

# %%
utifive = icd[
    icd['ICD9_DGNS_CD_1']
    .str.contains('^599', case = False, na=False)]
utifive.shape
# Out:
# (5574, 12)

# %%
utifive
# Out:
#               DESYNPUF_ID           CLM_ID  CLM_FROM_DT  CLM_THRU_DT  \
# 8        00016F745862898F  887953385848149     20081020     20081020
# 413      0004F0ABD505251D  887593389474703     20091122     20091122
# 577      00052705243EA128  887323388671747     20100409     20100409
# 654      0007F12A492FD25D  887353385949566     20080620     20080620
# 1436     00139C345A104F72  887833387309417     20091105     20091105
# 1850     0018C6D3871BA1E8  887663388998553     20080530     20080530
# 2376     001EA2F4DB30F105  887843386072543     20091028     20091028
# 2406     001EA2F4DB30F105  887163387079761     20100920     20100920
# 2452     001F135A720283D1  887333388854561     20090130     20090130
# 2483     001F135A720283D1  887863389371691     20091111     20091111
# 2977     002354398A00234E  887223388791946     20091127     20091127
# 3348     00256A69373687B4  887033387421747     20080428     20080428
# 3441     002578091E1953AF  887563388640427     20080313     20080313
# ...

# %% [markdown]
# > what is the count of various 599 prefixes?

# %%
new = utifive.groupby("ICD9_DGNS_CD_1")["ICD9_DGNS_CD_1"].count()
print (new)
# Out:
# ICD9_DGNS_CD_1
# 5990     1082
# 5991      111
# 5992      106
# 5993      112
# 5994      119
# 5995      116
# 5996      333
# 59960     380
# 59969     316
# 5997      377
# 59970     357
# 59971     342
# 59972     350
# 5998      325
# 59981     104
# 59982     116
# 59983     103
# 59984     121
# 59989     358
# 5999      346
# Name: ICD9_DGNS_CD_1, dtype: int64

# %% [markdown]
# ![](https://i.imgur.com/wHBeC7X.png) (according to [this site](https://dexur.com/icd9/599/))
#
# # ...⇧
# | FINDING: we want to focus on **5990**
