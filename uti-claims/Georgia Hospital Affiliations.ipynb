# %%
import pandas as pd
import bs4 as bs
import urllib.request
import re

# %%
file = '/home/xavier/data/Affiliations-gaurology.com.csv'

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#                                 NAME  \
# 0                  John Abbott, M.D.
# 1           Roosevelt Allen Jr. M.D.
# 2               Ronald Anglade, M.D.
# 3     David W. Banks, M.D., F.A.C.S.
# 4                Daniel Canter, M.D.
# ..                               ...
# 60         Tansy Ridings, MMSc, PA-C
# 61     Holly Shalhoop, MHS, PA-C, RD
# 62  Neil Trossevin Jr., B.S., P.A.-C
# 63         Karmon Janssen, D.O. M.S.
# 64                Charlotte Wu, M.D.
#
#                                                 PHOTO  \
# 0   https://www.gaurology.com/wp-content/uploads/a...
# 1   https://www.gaurology.com/wp-content/uploads/a...
# 2   https://www.gaurology.com/wp-content/uploads/a...
# 3   https://www.gaurology.com/wp-content/uploads/b...
# 4   https://www.gaurology.com/wp-content/uploads/d...
# ..                                                ...
# 60  https://www.gaurology.com/wp-content/uploads/r...
# 61  https://www.gaurology.com/wp-content/themes/en...
# ...

# %%
# hospitals = df.loc[df.DESCRIPTION.str.contains('hospital', case=False) | df.DESCRIPTION.str.contains('medical center',  case=False)]
# hospitals.shape

# a_string = "A string is more than its parts!"
# matches = ["more", "wholesome", "milk"]
# if any(x in a_string for x in matches):

# %%
def hospitalPrivilges(row):
    print (f'Working on {row}')
    request = urllib.request.Request(row,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36'})
    source = urllib.request.urlopen(request)
    soup = bs.BeautifulSoup(source,'html.parser')
    hcpinfo = soup.findAll('div',attrs={'class':'entry-content'})
    for h in hcpinfo:
         print (h.find(lambda tag:tag.name=="p" and "on staff" in tag.text))
# for link in links:
#     if link.find(text=re.compile("Edit")):
#         thelink = link
#         break

# %%
df.URL.apply(hospitalPrivilges)
# Out:
# Working on https://www.gaurology.com/our-physicians/physician/john-abbott/
# None
# Working on https://www.gaurology.com/our-physicians/physician/roosevelt-allen-jr/
# None
# None
# Working on https://www.gaurology.com/our-physicians/physician/ronald-anglade/
# <p>He is currently on staff at Emory Eastside Medical Center, Gwinnett Medical Center, Northside Hospital, Crawford-Long Hospital, and Dekalb Medical Center.</p>
# None
# Working on https://www.gaurology.com/our-physicians/physician/david-m-banks/
# None
# None
# Working on https://www.gaurology.com/our-physicians/physician/daniel-canter-m-d/
# None
# None
# Working on https://www.gaurology.com/our-physicians/physician/carl-capelouto/
# None
# None
# Working on https://www.gaurology.com/our-physicians/physician/darrell-j-carmen/
# None
# None
# Working on https://www.gaurology.com/our-physicians/physician/bert-chen/
# None
# None
# Working on https://www.gaurology.com/our-physicians/physician/fernando-a-duralde/
# None
# ...
