# %%
import pandas as pd
import numpy as np

# %%
# read full dataframe
df = pd.read_csv('gs://datacamp-202518.appspot.com/data/claims/cms_d/PartD_Prescriber_PUF_NPI_13.txt',sep='\t', lineterminator='\n')

# read only the columns I need
# df = pd.read_csv('gs://datacamp-202518.appspot.com/data/claims/cms_d/PartD_Prescriber_PUF_NPI_13.txt',sep='\t', lineterminator='\n')

# %%
# local storage
'''
/home/jupyter/data/cms
PartD_Prescriber_PUF_NPI_17.txt
PartD_Prescriber_PUF_NPI_Drug_17.txt
'''

# %%
df.shape
# Out:
# (1049299, 84)

# %%
df.head(10)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1003000126                    ENKESHAFI                   ARDALAN
# 1  1003000142                       KHALIL                    RASHID
# 2  1003000167                      ESCOBAR                     JULIO
# 3  1003000175                REYES-VASQUEZ                   BELINDA
# 4  1003000183                      CYPHERS                    DENNIS
# 5  1003000282                    BLAKEMORE                     ROSIE
# 6  1003000407                      GIRARDI                     DAVID
# 7  1003000415                      WEBSTER                  MARSHALL
# 8  1003000423                      VELOTTA                  JENNIFER
# 9  1003000480                    ROTHCHILD                     KEVIN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0               NaN              M.D.                     M                 I
# ...

# %%
list(df)
# Out:
# ['npi',
#  'nppes_provider_last_org_name',
#  'nppes_provider_first_name',
#  'nppes_provider_mi',
#  'nppes_credentials',
#  'nppes_provider_gender',
#  'nppes_entity_code',
#  'nppes_provider_street1',
#  'nppes_provider_street2',
#  'nppes_provider_city',
#  'nppes_provider_zip5',
#  'nppes_provider_zip4',
#  'nppes_provider_state',
#  'nppes_provider_country',
#  'specialty_description',
#  'description_flag',
#  'medicare_prvdr_enroll_status',
#  'total_claim_count',
#  'total_30_day_fill_count',
#  'total_drug_cost',
#  'total_day_supply',
#  'bene_count',
#  'ge65_suppress_flag',
#  'total_claim_count_ge65',
#  'total_30_day_fill_count_ge65',
#  'total_drug_cost_ge65',
#  'total_day_supply_ge65',
#  'bene_count_ge65_suppress_flag',
#  'bene_count_ge65',
#  'brand_suppress_flag',
#  'brand_claim_count',
#  'brand_drug_cost',
#  'generic_suppress_flag',
#  'generic_claim_count',
#  'generic_drug_cost',
#  'other_suppress_flag',
#  'other_claim_count',
#  'other_drug_cost',
# ...

# %%
impcols = [
'npi',
'nppes_provider_last_org_name',
'nppes_credentials',
'nppes_entity_code',
'nppes_provider_city',
'nppes_provider_zip5',
'nppes_provider_zip4',
'nppes_provider_state',
'specialty_description',
'description_flag',
'brand_suppress_flag',
'brand_claim_count',
'brand_drug_cost',
'generic_suppress_flag',
'generic_claim_count',
'generic_drug_cost',
'antibiotic_claim_count',
'antibiotic_drug_cost',
'antibiotic_bene_count',
]

# %%
slim = pd.read_csv('gs://datacamp-202518.appspot.com/data/claims/cms_d/PartD_Prescriber_PUF_NPI_13.txt',sep='\t', lineterminator='\n',usecols = impcols)

# %%
list(slim)
# Out:
# ['npi',
#  'nppes_provider_last_org_name',
#  'nppes_credentials',
#  'nppes_entity_code',
#  'nppes_provider_city',
#  'nppes_provider_zip5',
#  'nppes_provider_zip4',
#  'nppes_provider_state',
#  'specialty_description',
#  'description_flag',
#  'brand_suppress_flag',
#  'brand_claim_count',
#  'brand_drug_cost',
#  'generic_suppress_flag',
#  'generic_claim_count',
#  'generic_drug_cost',
#  'antibiotic_claim_count',
#  'antibiotic_drug_cost',
#  'antibiotic_bene_count']

# %%
slim.head(10)
# Out:
#           npi nppes_provider_last_org_name nppes_credentials  \
# 0  1003000126                    ENKESHAFI              M.D.
# 1  1003000142                       KHALIL              M.D.
# 2  1003000167                      ESCOBAR               DDS
# 3  1003000175                REYES-VASQUEZ            D.D.S.
# 4  1003000183                      CYPHERS             L.M.P
# 5  1003000282                    BLAKEMORE               FNP
# 6  1003000407                      GIRARDI              D.O.
# 7  1003000415                      WEBSTER              D.C.
# 8  1003000423                      VELOTTA              M.D.
# 9  1003000480                    ROTHCHILD                MD
#
#   nppes_entity_code nppes_provider_city  nppes_provider_zip5  \
# 0                 I          CUMBERLAND              21502.0
# 1                 I              TOLEDO              43623.0
# 2                 I              DAYTON              89403.0
# ...

# %%
specialities = slim.specialty_description.unique()
s = pd.Series(specialities)
s.to_csv('/home/jupyter/data/cms/doctor-specialisms.csv',header=None, index=None)

# %%
impspecialties = [
'Internal Medicine',
'Nurse Practitioner',
'Family Practice',
'Obstetrics/Gynecology',
'Urology',
'Physician Assistant',
'Infectious Disease',
'Preventive Medicine',
'General Practice',
'Clinic/Center',
'Geriatric Medicine',
'Hospital (Dmercs Only)',
'Licensed Practical Nurse',
'Exclusive Provider Organization',
'Case Manager/Care Coordinator',
'Certified Clinical Nurse Specialist',
'Critical Care (Intensivists)',
'Family Medicine',
'Registered Nurse',
'General Acute Care Hospital',
'Multispecialty Clinic/Group Practice',
'Gynecological/Oncology',
'Licensed Vocational Nurse',
'Health Maintenance Organization',
'Community/Behavioral Health',
'Medical Genetics',
'Assisted Living Facility',
'Preferred Provider Organization',
'Obstetrics & Gynecology',
'Nursing Home Administrator',
'Nursing Care',
'Skilled Nursing Facility'
]
