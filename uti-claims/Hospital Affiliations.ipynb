# %%
import pandas as pd

# %%
file = '/home/xavier/data/Affiliations-urologycentersalabama.com.csv'

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#                                NAME  PHOTO  \
# 0                Dr. Michael Bivins    NaN
# 1                  Dr. Taylor Bragg    NaN
# 2                   Dr. Eric Brewer    NaN
# 3                  Dr. Charles Bugg    NaN
# 4                   Dr. Lee Burnett    NaN
# 5                  Dr. Jason Burrus    NaN
# 6               Dr. Brian Christine    NaN
# 7                     Dr. Jared Cox    NaN
# 8                  Dr. Amanda Crowe    NaN
# 9               Dr. Mark DeGuenther    NaN
# 10                  Dr. Mell Duggan    NaN
# 11                Dr. Elbert Duncan    NaN
# 12              Dr. Joelle Hamilton    NaN
# 13               Dr. Lee Hammontree    NaN
# 14                 Dr. Leon Hamrick    NaN
# 15                Dr. Thomas Holley    NaN
# 16             Dr. Rupa K. Kitchens    NaN
# 17                 Dr. Brian Larson    NaN
# 18                  Dr. Austin Lutz    NaN
# 19                Dr. Nicole Massie    NaN
# 20                Dr. Patrick Mills    NaN
# ...

# %%
hospitals = df.loc[df.DESCRIPTION.str.contains('hospital', case=False) | df.DESCRIPTION.str.contains('medical center',  case=False)]
hospitals.shape
# Out:
# (17, 3)

# %%
hospitals
# Out:
#                       NAME  PHOTO  \
# 0       Dr. Michael Bivins    NaN
# 1         Dr. Taylor Bragg    NaN
# 2          Dr. Eric Brewer    NaN
# 8         Dr. Amanda Crowe    NaN
# 10         Dr. Mell Duggan    NaN
# 11       Dr. Elbert Duncan    NaN
# 13      Dr. Lee Hammontree    NaN
# 14        Dr. Leon Hamrick    NaN
# 15       Dr. Thomas Holley    NaN
# 17        Dr. Brian Larson    NaN
# 20       Dr. Patrick Mills    NaN
# 21    Dr. Jason Moellinger    NaN
# 26        Dr. Paula Rookis    NaN
# 29          Dr. Brian Wade    NaN
# 30       Dr. John Wilbanks    NaN
# 32  Jonathan Barnett, PA-C    NaN
# 40         Sadie Orr, CRNP    NaN
#
#                                           DESCRIPTION
# 0   Dr. Vincent Michael Bivins received his Bachel...
# 1   Dr. Bragg attended Birmingham-Southern College...
# 2   Dr. Eric Brewer is a native of Birmingham, AL ...
# 8   Dr. Amanda Crowe has been a valued member of U...
# 10  Dr. Duggan graduated from Washington and Lee U...
# ...
