# %%
import pandas as pd
from sodapy import Socrata

# %%
client = Socrata("data.cms.gov", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("x3vv-caiy", limit=2000)

# %%
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#               reference_period                        type_of_service  \
# 0     2014-10-01 to 2015-09-30  Ambulance (Emergency & Non-Emergency)
# 1     2014-10-01 to 2015-09-30  Ambulance (Emergency & Non-Emergency)
# 2     2014-10-01 to 2015-09-30  Ambulance (Emergency & Non-Emergency)
# 3     2014-10-01 to 2015-09-30  Ambulance (Emergency & Non-Emergency)
# 4     2014-10-01 to 2015-09-30  Ambulance (Emergency & Non-Emergency)
# ...                        ...                                    ...
# 1995  2014-10-01 to 2015-09-30  Ambulance (Emergency & Non-Emergency)
# 1996  2014-10-01 to 2015-09-30  Ambulance (Emergency & Non-Emergency)
# 1997  2014-10-01 to 2015-09-30  Ambulance (Emergency & Non-Emergency)
# 1998  2014-10-01 to 2015-09-30  Ambulance (Emergency & Non-Emergency)
# 1999  2014-10-01 to 2015-09-30  Ambulance (Emergency & Non-Emergency)
#
#          aggregation_level    state      county  \
# 0     NATION + TERRITORIES  --ALL--     --ALL--
# ...

# %%
newresults = client.get("x3vv-caiy", type_of_service="telemedicine", limit=2000)

# %%
newresults_df = pd.DataFrame.from_records(newresults)

# %%
newresults_df.shape
# Out:
# (0, 0)
