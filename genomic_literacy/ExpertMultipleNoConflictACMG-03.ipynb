# %%
import pandas as pd
import re

# %%
datadir = '/Users/xthomas/Documents/data/guide/'
clinvar_file = 'variant_summary_02.txt' # Updated 5/21/2018

# %% [markdown]
# # First thing, download and survey the 'Clinvar' data
#
# ## ➜ ClinVar is a freely accessible, public archive of reports of the relationships among human variations and phenotypes, with supporting evidence.
#
# + A phenotype results from the expression of an organism's genetic code, its genotype, as well as the influence of environmental factors and the interactions between the two. [Wikipedia](https://en.wikipedia.org/wiki/Phenotype)
# + File is from **[THIS FTP DIRECTORY](ftp://ftp.ncbi.nlm.nih.gov/pub/clinvar/tab_delimited/)** (which is updated monthly)
# + ** Download this file [Variant_summary.txt](ftp://ftp.ncbi.nlm.nih.gov/pub/clinvar/tab_delimited/variant_summary.txt.gz)** which is a 809K row dataset listing

# %%
clinvar = pd.read_csv(datadir + clinvar_file, sep='\t', lineterminator='\n')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
list(clinvar)
# Out:
# ['#AlleleID',
#  'Type',
#  'Name',
#  'GeneID',
#  'GeneSymbol',
#  'HGNC_ID',
#  'ClinicalSignificance',
#  'ClinSigSimple',
#  'LastEvaluated',
#  'RS# (dbSNP)',
#  'nsv/esv (dbVar)',
#  'RCVaccession',
#  'PhenotypeIDS',
#  'PhenotypeList',
#  'Origin',
#  'OriginSimple',
#  'Assembly',
#  'ChromosomeAccession',
#  'Chromosome',
#  'Start',
#  'Stop',
#  'ReferenceAllele',
#  'AlternateAllele',
#  'Cytogenetic',
#  'ReviewStatus',
#  'NumberSubmitters',
#  'Guidelines',
#  'TestedInGTR',
#  'OtherIDs',
#  'SubmitterCategories',
#  'VariationID']

# %%
# count the rows of data
clinvar.shape
# Out:
# (811417, 31)

# %%
# Work with Human Reference Genome #38
latest = clinvar[clinvar['Assembly'] == 'GRCh38']
latest.shape
# Out:
# (389089, 31)

# %%
# Further filter the dataset down by these 'authoritative' flags
# from the 'Review Status' column

authoritative = latest[
    (latest['ReviewStatus'] == 'criteria provided, multiple submitters, no conflicts') | 
    (latest['ReviewStatus'] == 'practice guideline') | 
    (latest['ReviewStatus'] == 'reviewed by expert panel') 
]
authoritative.shape
# Out:
# (62166, 31)

# %%
authstub = authoritative.filter(['PhenotypeIDS','PhenotypeList','ReviewStatus']).iloc[0:1500]
authstub.shape
# Out:
# (1500, 3)

# %%
authstub
# Out:
#                                             PhenotypeIDS  \
# 11     MeSH:D030342,MedGen:C0950123;MedGen:C1838979,O...
# 20     MedGen:C3469186,OMIM:235200;MedGen:C0392514,SN...
# 57       MedGen:C3150878,OMIM:613616,Orphanet:ORPHA93600
# 70           MedGen:C1419614,OMIM:606068;MedGen:CN517202
# 72           MedGen:C1419614,OMIM:606068;MedGen:CN517202
# 74                           MedGen:C1419614,OMIM:606068
# 105    MedGen:C3150801,OMIM:613559,Orphanet:ORPHA2549...
# 107          MedGen:C3553886,OMIM:614852;MedGen:CN517202
# 184    na;MedGen:C0342701,OMIM:275350,Orphanet:ORPHA8...
# 223    MedGen:CN230736;na;Human Phenotype Ontology:HP...
# 227    Human Phenotype Ontology:HP:0002156,MedGen:C00...
# 229    MedGen:CN230736;na;Human Phenotype Ontology:HP...
# 233    MedGen:C3150344,OMIM:236200,Orphanet:ORPHA394;...
# 239    MedGen:CN230736;MedGen:C3150344,OMIM:236200,Or...
# 241    na;MedGen:C3150344,OMIM:236200,Orphanet:ORPHA3...
# 246    Human Phenotype Ontology:HP:0002156,MedGen:C00...
# 252    MedGen:CN230736;MedGen:C3150344,OMIM:236200,Or...
# 254    Human Phenotype Ontology:HP:0002156,MedGen:C00...
# 380    MeSH:D030342,MedGen:C0950123;Human Phenotype O...
# 471                                   na;MedGen:CN169374
# 517    MedGen:CN230736;MedGen:C2750995,OMIM:613172;Me...
# 519          MedGen:C2750995,OMIM:613172;MedGen:CN517202
# 521    MedGen:C2750995,OMIM:613172;EFO:EFO_0000407,Hu...
# 523    MedGen:C2750995,OMIM:613172;MedGen:C0340427,Or...
# 572    MedGen:CN517202;MedGen:CN169374;MedGen:C126403...
# 657    MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 659    MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 663    MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 688    MedGen:C0027672,SNOMED CT:699346009;MedGen:C18...
# 691    MeSH:D030342,MedGen:C0950123;MedGen:C0027831,O...
# ...                                                  ...
# 29671  MedGen:CN239285;MedGen:C1838564,OMIM:600155;Me...
# 29686        MedGen:C3150975,OMIM:613712;MedGen:CN169374
# 29717  MedGen:C0872218,OMIM:603041,Orphanet:ORPHA298;...
# 29742  MedGen:C0027672,SNOMED CT:699346009;MeSH:D0187...
# 29747  MedGen:C0027672,SNOMED CT:699346009;MeSH:D0187...
# 29754  MedGen:C0027672,SNOMED CT:699346009;na;MeSH:D0...
# 29761  MedGen:C0027672,SNOMED CT:699346009;MeSH:D0187...
# 29763  MedGen:C0027672,SNOMED CT:699346009;MedGen:C40...
# 29780  MedGen:C0027672,SNOMED CT:699346009;MeSH:D0187...
# 29806  Human Phenotype Ontology:HP:0004381,MedGen:C00...
# 29852  MedGen:C1843247,OMIM:607678,Orphanet:ORPHA1010...
# 29879              na;MedGen:C0393615;na;MedGen:CN169374
# 29922  MeSH:D030342,MedGen:C0950123;MedGen:C0268138,O...
# 29935  MedGen:C0265257,OMIM:263750,SNOMED CT:66038001...
# 29950  MedGen:CN236460;MedGen:C2675718;MedGen:C267572...
# 29952  MedGen:C0349788,Orphanet:ORPHA247,SNOMED CT:25...
# 29956  MedGen:C0349788,Orphanet:ORPHA247,SNOMED CT:25...
# 29966  MedGen:C0349788,Orphanet:ORPHA247,SNOMED CT:25...
# 29985  MedGen:C1832370,OMIM:601419,Orphanet:ORPHA9890...
# 30027  MedGen:C0349788,Orphanet:ORPHA247,SNOMED CT:25...
# 30094  MedGen:C1837156;MedGen:CN236466;MedGen:CN23647...
# 30108  MedGen:C2674941;MedGen:C1836024;MedGen:C183602...
# 30113  MedGen:C1836024;MedGen:C1836026;MedGen:CN23650...
# 30115    MedGen:C1836024;MedGen:CN236508;MedGen:CN517202
# 30144                              na;na;MedGen:CN236545
# 30158  MedGen:C1864880,OMIM:610424;MedGen:C0021390,Or...
# 30168  MedGen:C1836892,OMIM:609048;MedGen:C0027672,SN...
# 30284        MedGen:C0812437,OMIM:164200;MedGen:CN517202
# 30294  MedGen:C1844678,OMIM:304400,Orphanet:ORPHA383;...
# 30296  MedGen:C2675750,OMIM:601544;MedGen:C2673759,OM...
#
#                                            PhenotypeList  \
# 11     Inborn genetic diseases;Mitochondrial complex ...
# 20     Hemochromatosis type 1;Hereditary hemochromato...
# 57                       Primary hyperoxaluria, type III
# 70                  Retinitis pigmentosa 28;not provided
# 72                  Retinitis pigmentosa 28;not provided
# 74                               Retinitis pigmentosa 28
# 105    Combined oxidative phosphorylation deficiency ...
# 107    Primary autosomal recessive microcephaly 9;not...
# 184    TCN2 POLYMORPHISM;Transcobalamin II deficiency...
# 223    Cardiovascular phenotype;HYPERHOMOCYSTEINEMIA,...
# 227    Homocystinuria;Homocystinuria due to CBS defic...
# 229    Cardiovascular phenotype;HYPERHOMOCYSTEINEMIA,...
# 233    Homocystinuria due to CBS deficiency;Homocysti...
# 239    Cardiovascular phenotype;Homocystinuria due to...
# 241    HYPERHOMOCYSTEINEMIA, THROMBOTIC, CBS-RELATED;...
# 246    Homocystinuria;Homocystinuria due to CBS defic...
# 252    Cardiovascular phenotype;Homocystinuria due to...
# 254    Homocystinuria;Homocystinuria due to CBS defic...
# 380    Inborn genetic diseases;Joubert syndrome;Joube...
# 471    NADH-CYTOCHROME b5 REDUCTASE POLYMORPHISM;not ...
# 517    Cardiovascular phenotype;Dilated cardiomyopath...
# 519              Dilated cardiomyopathy 1DD;not provided
# 521    Dilated cardiomyopathy 1DD;Primary dilated car...
# 523    Dilated cardiomyopathy 1DD;Familial dilated ca...
# 572    not provided;not specified;von Willebrand dise...
# 657    Hereditary cancer-predisposing syndrome;Neurof...
# 659    Hereditary cancer-predisposing syndrome;Neurof...
# 663    Hereditary cancer-predisposing syndrome;Neurof...
# 688    Hereditary cancer-predisposing syndrome;Neurof...
# 691    Inborn genetic diseases;Neurofibromatosis, typ...
# ...                                                  ...
# 29671  Hirschsprung Disease, Recessive;Hirschsprung d...
# 29686               Hirschsprung disease 4;not specified
# 29717  Mitochondrial DNA depletion syndrome 1 (MNGIE ...
# 29742  Hereditary cancer-predisposing syndrome;Multip...
# 29747  Hereditary cancer-predisposing syndrome;Multip...
# 29754  Hereditary cancer-predisposing syndrome;Metast...
# 29761  Hereditary cancer-predisposing syndrome;Multip...
# 29763  Hereditary cancer-predisposing syndrome;Lipoma...
# 29780  Hereditary cancer-predisposing syndrome;Multip...
# 29806           Supravalvar aortic stenosis;not provided
# 29852  Charcot-Marie-Tooth disease, demyelinating, ty...
# 29879  Essential tremor, susceptibility to;Hereditary...
# 29922  Inborn genetic diseases;Xeroderma pigmentosum,...
# 29935                       Miller syndrome;not provided
# 29950  Alkylating Agents, anthracyclines and related ...
# 29952  Arrhythmogenic right ventricular cardiomyopath...
# 29956  Arrhythmogenic right ventricular cardiomyopath...
# 29966  Arrhythmogenic right ventricular cardiomyopath...
# 29985               Myofibrillar myopathy 1;not provided
# 30027  Arrhythmogenic right ventricular cardiomyopath...
# 30094  Debrisoquine, poor metabolism of;amitriptyline...
# 30108  Clopidogrel response;Mephenytoin, poor metabol...
# 30113  Mephenytoin, poor metabolism of;Proguanil, poo...
# 30115  Mephenytoin, poor metabolism of;clopidogrel re...
# 30144  CYP3A4 PROMOTER POLYMORPHISM;Cyp3a4-v;tacrolim...
# 30158  Hepatitis b virus, susceptibility to;Inflammat...
# 30168  Cutaneous malignant melanoma 3;Hereditary canc...
# 30284           Oculodentodigital dysplasia;not provided
# 30294  Deafness, X-linked 2;Deafness, autosomal domin...
# 30296  Deafness, autosomal dominant 3a;Deafness, auto...
#
#                                             ReviewStatus
# 11     criteria provided, multiple submitters, no con...
# 20     criteria provided, multiple submitters, no con...
# 57     criteria provided, multiple submitters, no con...
# 70     criteria provided, multiple submitters, no con...
# 72     criteria provided, multiple submitters, no con...
# 74     criteria provided, multiple submitters, no con...
# 105    criteria provided, multiple submitters, no con...
# 107    criteria provided, multiple submitters, no con...
# 184    criteria provided, multiple submitters, no con...
# 223    criteria provided, multiple submitters, no con...
# 227    criteria provided, multiple submitters, no con...
# 229    criteria provided, multiple submitters, no con...
# 233    criteria provided, multiple submitters, no con...
# 239    criteria provided, multiple submitters, no con...
# 241    criteria provided, multiple submitters, no con...
# 246    criteria provided, multiple submitters, no con...
# 252    criteria provided, multiple submitters, no con...
# 254    criteria provided, multiple submitters, no con...
# 380    criteria provided, multiple submitters, no con...
# 471    criteria provided, multiple submitters, no con...
# 517    criteria provided, multiple submitters, no con...
# 519    criteria provided, multiple submitters, no con...
# 521    criteria provided, multiple submitters, no con...
# 523    criteria provided, multiple submitters, no con...
# 572    criteria provided, multiple submitters, no con...
# 657    criteria provided, multiple submitters, no con...
# 659    criteria provided, multiple submitters, no con...
# 663    criteria provided, multiple submitters, no con...
# 688    criteria provided, multiple submitters, no con...
# 691    criteria provided, multiple submitters, no con...
# ...                                                  ...
# 29671  criteria provided, multiple submitters, no con...
# 29686  criteria provided, multiple submitters, no con...
# 29717  criteria provided, multiple submitters, no con...
# 29742  criteria provided, multiple submitters, no con...
# 29747  criteria provided, multiple submitters, no con...
# 29754  criteria provided, multiple submitters, no con...
# 29761  criteria provided, multiple submitters, no con...
# 29763  criteria provided, multiple submitters, no con...
# 29780  criteria provided, multiple submitters, no con...
# 29806  criteria provided, multiple submitters, no con...
# 29852  criteria provided, multiple submitters, no con...
# 29879  criteria provided, multiple submitters, no con...
# 29922  criteria provided, multiple submitters, no con...
# 29935  criteria provided, multiple submitters, no con...
# 29950                           reviewed by expert panel
# 29952  criteria provided, multiple submitters, no con...
# 29956  criteria provided, multiple submitters, no con...
# 29966  criteria provided, multiple submitters, no con...
# 29985  criteria provided, multiple submitters, no con...
# 30027  criteria provided, multiple submitters, no con...
# 30094                           reviewed by expert panel
# 30108                           reviewed by expert panel
# 30113                           reviewed by expert panel
# 30115                           reviewed by expert panel
# 30144                           reviewed by expert panel
# 30158  criteria provided, multiple submitters, no con...
# 30168  criteria provided, multiple submitters, no con...
# 30284  criteria provided, multiple submitters, no con...
# 30294  criteria provided, multiple submitters, no con...
# 30296  criteria provided, multiple submitters, no con...
#
# [1500 rows x 3 columns]

# %% [markdown]
# ## Time to start matching the OMIM tags
#
# + First order is to find OMIM tags that match the **59 ACMG Recommendations Diseases**
# + Import this file: [ACMG Recommendations for Reporting of Incidental Findings in Clinical Exome and Genome Sequencing](https://www.ncbi.nlm.nih.gov/clinvar/docs/acmg/)

# %%
# Import Disease names and OMIM tags and convert to a list
acmg = pd.read_csv(datadir + 'ACMG_Conditions_OMIM.csv')
acmgtags = acmg.ACMGTAGS.tolist()

# %%
# function to write OMIM TAGS to a new Column
def omim_tags (x):
    # Find anything that has an OMIM tag, from 1 to 6 numerals long
    res = re.findall(r"(?:OMIM:(\d{1,6}))",x)
    if res:
        return res
    else:
#         print("NA")
         return ("NA")

# %%
authstub['OMIMTAGS'] = authoritative.PhenotypeIDS.apply(omim_tags)

# %%
authstub
# Out:
#                                             PhenotypeIDS  \
# 11     MeSH:D030342,MedGen:C0950123;MedGen:C1838979,O...
# 20     MedGen:C3469186,OMIM:235200;MedGen:C0392514,SN...
# 57       MedGen:C3150878,OMIM:613616,Orphanet:ORPHA93600
# 70           MedGen:C1419614,OMIM:606068;MedGen:CN517202
# 72           MedGen:C1419614,OMIM:606068;MedGen:CN517202
# 74                           MedGen:C1419614,OMIM:606068
# 105    MedGen:C3150801,OMIM:613559,Orphanet:ORPHA2549...
# 107          MedGen:C3553886,OMIM:614852;MedGen:CN517202
# 184    na;MedGen:C0342701,OMIM:275350,Orphanet:ORPHA8...
# 223    MedGen:CN230736;na;Human Phenotype Ontology:HP...
# 227    Human Phenotype Ontology:HP:0002156,MedGen:C00...
# 229    MedGen:CN230736;na;Human Phenotype Ontology:HP...
# 233    MedGen:C3150344,OMIM:236200,Orphanet:ORPHA394;...
# 239    MedGen:CN230736;MedGen:C3150344,OMIM:236200,Or...
# 241    na;MedGen:C3150344,OMIM:236200,Orphanet:ORPHA3...
# 246    Human Phenotype Ontology:HP:0002156,MedGen:C00...
# 252    MedGen:CN230736;MedGen:C3150344,OMIM:236200,Or...
# 254    Human Phenotype Ontology:HP:0002156,MedGen:C00...
# 380    MeSH:D030342,MedGen:C0950123;Human Phenotype O...
# 471                                   na;MedGen:CN169374
# 517    MedGen:CN230736;MedGen:C2750995,OMIM:613172;Me...
# 519          MedGen:C2750995,OMIM:613172;MedGen:CN517202
# 521    MedGen:C2750995,OMIM:613172;EFO:EFO_0000407,Hu...
# 523    MedGen:C2750995,OMIM:613172;MedGen:C0340427,Or...
# 572    MedGen:CN517202;MedGen:CN169374;MedGen:C126403...
# 657    MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 659    MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 663    MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 688    MedGen:C0027672,SNOMED CT:699346009;MedGen:C18...
# 691    MeSH:D030342,MedGen:C0950123;MedGen:C0027831,O...
# ...                                                  ...
# 29671  MedGen:CN239285;MedGen:C1838564,OMIM:600155;Me...
# 29686        MedGen:C3150975,OMIM:613712;MedGen:CN169374
# 29717  MedGen:C0872218,OMIM:603041,Orphanet:ORPHA298;...
# 29742  MedGen:C0027672,SNOMED CT:699346009;MeSH:D0187...
# 29747  MedGen:C0027672,SNOMED CT:699346009;MeSH:D0187...
# 29754  MedGen:C0027672,SNOMED CT:699346009;na;MeSH:D0...
# 29761  MedGen:C0027672,SNOMED CT:699346009;MeSH:D0187...
# 29763  MedGen:C0027672,SNOMED CT:699346009;MedGen:C40...
# 29780  MedGen:C0027672,SNOMED CT:699346009;MeSH:D0187...
# 29806  Human Phenotype Ontology:HP:0004381,MedGen:C00...
# 29852  MedGen:C1843247,OMIM:607678,Orphanet:ORPHA1010...
# 29879              na;MedGen:C0393615;na;MedGen:CN169374
# 29922  MeSH:D030342,MedGen:C0950123;MedGen:C0268138,O...
# 29935  MedGen:C0265257,OMIM:263750,SNOMED CT:66038001...
# 29950  MedGen:CN236460;MedGen:C2675718;MedGen:C267572...
# 29952  MedGen:C0349788,Orphanet:ORPHA247,SNOMED CT:25...
# 29956  MedGen:C0349788,Orphanet:ORPHA247,SNOMED CT:25...
# 29966  MedGen:C0349788,Orphanet:ORPHA247,SNOMED CT:25...
# 29985  MedGen:C1832370,OMIM:601419,Orphanet:ORPHA9890...
# 30027  MedGen:C0349788,Orphanet:ORPHA247,SNOMED CT:25...
# 30094  MedGen:C1837156;MedGen:CN236466;MedGen:CN23647...
# 30108  MedGen:C2674941;MedGen:C1836024;MedGen:C183602...
# 30113  MedGen:C1836024;MedGen:C1836026;MedGen:CN23650...
# 30115    MedGen:C1836024;MedGen:CN236508;MedGen:CN517202
# 30144                              na;na;MedGen:CN236545
# 30158  MedGen:C1864880,OMIM:610424;MedGen:C0021390,Or...
# 30168  MedGen:C1836892,OMIM:609048;MedGen:C0027672,SN...
# 30284        MedGen:C0812437,OMIM:164200;MedGen:CN517202
# 30294  MedGen:C1844678,OMIM:304400,Orphanet:ORPHA383;...
# 30296  MedGen:C2675750,OMIM:601544;MedGen:C2673759,OM...
#
#                                            PhenotypeList  \
# 11     Inborn genetic diseases;Mitochondrial complex ...
# 20     Hemochromatosis type 1;Hereditary hemochromato...
# 57                       Primary hyperoxaluria, type III
# 70                  Retinitis pigmentosa 28;not provided
# 72                  Retinitis pigmentosa 28;not provided
# 74                               Retinitis pigmentosa 28
# 105    Combined oxidative phosphorylation deficiency ...
# 107    Primary autosomal recessive microcephaly 9;not...
# 184    TCN2 POLYMORPHISM;Transcobalamin II deficiency...
# 223    Cardiovascular phenotype;HYPERHOMOCYSTEINEMIA,...
# 227    Homocystinuria;Homocystinuria due to CBS defic...
# 229    Cardiovascular phenotype;HYPERHOMOCYSTEINEMIA,...
# 233    Homocystinuria due to CBS deficiency;Homocysti...
# 239    Cardiovascular phenotype;Homocystinuria due to...
# 241    HYPERHOMOCYSTEINEMIA, THROMBOTIC, CBS-RELATED;...
# 246    Homocystinuria;Homocystinuria due to CBS defic...
# 252    Cardiovascular phenotype;Homocystinuria due to...
# 254    Homocystinuria;Homocystinuria due to CBS defic...
# 380    Inborn genetic diseases;Joubert syndrome;Joube...
# 471    NADH-CYTOCHROME b5 REDUCTASE POLYMORPHISM;not ...
# 517    Cardiovascular phenotype;Dilated cardiomyopath...
# 519              Dilated cardiomyopathy 1DD;not provided
# 521    Dilated cardiomyopathy 1DD;Primary dilated car...
# 523    Dilated cardiomyopathy 1DD;Familial dilated ca...
# 572    not provided;not specified;von Willebrand dise...
# 657    Hereditary cancer-predisposing syndrome;Neurof...
# 659    Hereditary cancer-predisposing syndrome;Neurof...
# 663    Hereditary cancer-predisposing syndrome;Neurof...
# 688    Hereditary cancer-predisposing syndrome;Neurof...
# 691    Inborn genetic diseases;Neurofibromatosis, typ...
# ...                                                  ...
# 29671  Hirschsprung Disease, Recessive;Hirschsprung d...
# 29686               Hirschsprung disease 4;not specified
# 29717  Mitochondrial DNA depletion syndrome 1 (MNGIE ...
# 29742  Hereditary cancer-predisposing syndrome;Multip...
# 29747  Hereditary cancer-predisposing syndrome;Multip...
# 29754  Hereditary cancer-predisposing syndrome;Metast...
# 29761  Hereditary cancer-predisposing syndrome;Multip...
# 29763  Hereditary cancer-predisposing syndrome;Lipoma...
# 29780  Hereditary cancer-predisposing syndrome;Multip...
# 29806           Supravalvar aortic stenosis;not provided
# 29852  Charcot-Marie-Tooth disease, demyelinating, ty...
# 29879  Essential tremor, susceptibility to;Hereditary...
# 29922  Inborn genetic diseases;Xeroderma pigmentosum,...
# 29935                       Miller syndrome;not provided
# 29950  Alkylating Agents, anthracyclines and related ...
# 29952  Arrhythmogenic right ventricular cardiomyopath...
# 29956  Arrhythmogenic right ventricular cardiomyopath...
# 29966  Arrhythmogenic right ventricular cardiomyopath...
# 29985               Myofibrillar myopathy 1;not provided
# 30027  Arrhythmogenic right ventricular cardiomyopath...
# 30094  Debrisoquine, poor metabolism of;amitriptyline...
# 30108  Clopidogrel response;Mephenytoin, poor metabol...
# 30113  Mephenytoin, poor metabolism of;Proguanil, poo...
# 30115  Mephenytoin, poor metabolism of;clopidogrel re...
# 30144  CYP3A4 PROMOTER POLYMORPHISM;Cyp3a4-v;tacrolim...
# 30158  Hepatitis b virus, susceptibility to;Inflammat...
# 30168  Cutaneous malignant melanoma 3;Hereditary canc...
# 30284           Oculodentodigital dysplasia;not provided
# 30294  Deafness, X-linked 2;Deafness, autosomal domin...
# 30296  Deafness, autosomal dominant 3a;Deafness, auto...
#
#                                             ReviewStatus  \
# 11     criteria provided, multiple submitters, no con...
# 20     criteria provided, multiple submitters, no con...
# 57     criteria provided, multiple submitters, no con...
# 70     criteria provided, multiple submitters, no con...
# 72     criteria provided, multiple submitters, no con...
# 74     criteria provided, multiple submitters, no con...
# 105    criteria provided, multiple submitters, no con...
# 107    criteria provided, multiple submitters, no con...
# 184    criteria provided, multiple submitters, no con...
# 223    criteria provided, multiple submitters, no con...
# 227    criteria provided, multiple submitters, no con...
# 229    criteria provided, multiple submitters, no con...
# 233    criteria provided, multiple submitters, no con...
# 239    criteria provided, multiple submitters, no con...
# 241    criteria provided, multiple submitters, no con...
# 246    criteria provided, multiple submitters, no con...
# 252    criteria provided, multiple submitters, no con...
# 254    criteria provided, multiple submitters, no con...
# 380    criteria provided, multiple submitters, no con...
# 471    criteria provided, multiple submitters, no con...
# 517    criteria provided, multiple submitters, no con...
# 519    criteria provided, multiple submitters, no con...
# 521    criteria provided, multiple submitters, no con...
# 523    criteria provided, multiple submitters, no con...
# 572    criteria provided, multiple submitters, no con...
# 657    criteria provided, multiple submitters, no con...
# 659    criteria provided, multiple submitters, no con...
# 663    criteria provided, multiple submitters, no con...
# 688    criteria provided, multiple submitters, no con...
# 691    criteria provided, multiple submitters, no con...
# ...                                                  ...
# 29671  criteria provided, multiple submitters, no con...
# 29686  criteria provided, multiple submitters, no con...
# 29717  criteria provided, multiple submitters, no con...
# 29742  criteria provided, multiple submitters, no con...
# 29747  criteria provided, multiple submitters, no con...
# 29754  criteria provided, multiple submitters, no con...
# 29761  criteria provided, multiple submitters, no con...
# 29763  criteria provided, multiple submitters, no con...
# 29780  criteria provided, multiple submitters, no con...
# 29806  criteria provided, multiple submitters, no con...
# 29852  criteria provided, multiple submitters, no con...
# 29879  criteria provided, multiple submitters, no con...
# 29922  criteria provided, multiple submitters, no con...
# 29935  criteria provided, multiple submitters, no con...
# 29950                           reviewed by expert panel
# 29952  criteria provided, multiple submitters, no con...
# 29956  criteria provided, multiple submitters, no con...
# 29966  criteria provided, multiple submitters, no con...
# 29985  criteria provided, multiple submitters, no con...
# 30027  criteria provided, multiple submitters, no con...
# 30094                           reviewed by expert panel
# 30108                           reviewed by expert panel
# 30113                           reviewed by expert panel
# 30115                           reviewed by expert panel
# 30144                           reviewed by expert panel
# 30158  criteria provided, multiple submitters, no con...
# 30168  criteria provided, multiple submitters, no con...
# 30284  criteria provided, multiple submitters, no con...
# 30294  criteria provided, multiple submitters, no con...
# 30296  criteria provided, multiple submitters, no con...
#
#                                                 OMIMTAGS
# 11                                              [252010]
# 20                                      [235200, 612635]
# 57                                              [613616]
# 70                                              [606068]
# 72                                              [606068]
# 74                                              [606068]
# 105                                             [613559]
# 107                                             [614852]
# 184                                             [275350]
# 223                                             [236200]
# 227                                             [236200]
# 229                                             [236200]
# 233                                             [236200]
# 239                                             [236200]
# 241                                             [236200]
# 246                                             [236200]
# 252                                             [236200]
# 254                                             [236200]
# 380                                     [608091, 603194]
# 471                                                   NA
# 517                                     [613172, 613426]
# 519                                             [613172]
# 521                                             [613172]
# 523                                             [613172]
# 572                                     [193400, 613554]
# 657                                             [162200]
# 659                                             [162200]
# 663                                             [162200]
# 688                                     [162210, 162200]
# 691                                             [162200]
# ...                                                  ...
# 29671                                   [600155, 193510]
# 29686                                           [613712]
# 29717                                           [603041]
# 29742                                           [131100]
# 29747                                           [131100]
# 29754                                           [131100]
# 29761                                           [131100]
# 29763                                           [131100]
# 29780                                           [131100]
# 29806                                           [185500]
# 29852                                   [607678, 145900]
# 29879                                                 NA
# 29922                                           [278730]
# 29935                                           [263750]
# 29950                                           [211980]
# 29952                                           [610193]
# 29956                                           [610193]
# 29966                                           [610193]
# 29985                                           [601419]
# 30027                                           [610476]
# 30094                                                 NA
# 30108                                                 NA
# 30113                                                 NA
# 30115                                                 NA
# 30144                                                 NA
# 30158                                           [610424]
# 30168                                   [609048, 254500]
# 30284                                           [164200]
# 30294  [304400, 601544, 601544, 220290, 220290, 60254...
# 30296                                   [601544, 220290]
#
# [1500 rows x 4 columns]

# %%
# authstub.to_csv(datadir + 'auth_1500_v1.csv')

# %%
# function to write "OMIM > ACMG" matches to a new Column
# you want this to match on ROW 246 of the Google Sheet
def acmg_matches (x):
    # Find anything that has an OMIM tag, from 4 to 6 numerals long
    res = re.findall(r"(?:OMIM:(\d{4,6}))",x)
    print ("On this line, there are {} OMIM Tags".format(len(res)))
    if res:
        for match in res:
            # Check if matches against ACMG
            if int(match) in acmgtags:
                print ("ACMG Match Found here: {}".format(match))
            else:
                print ("{} (NOT ACMG)".format(match))
    else:
        print ("NO OMIM")
#          return ("NA")

# %%
test = authstub.PhenotypeIDS.iloc[275:285].apply(acmg_matches)
# Out:
# On this line, there are 2 OMIM Tags
# 252500 NO ACMG
# 252600 NO ACMG
# On this line, there are 3 OMIM Tags
# 232500 NO ACMG
# 232500 NO ACMG
# 263570 NO ACMG
# On this line, there are 1 OMIM Tags
# 216550 NO ACMG
# On this line, there are 1 OMIM Tags
# 203750 NO ACMG
# On this line, there are 2 OMIM Tags
# ACMG Match Found here: 143890
# ACMG Match Found here: 603776
# On this line, there are 1 OMIM Tags
# 273800 NO ACMG
# On this line, there are 1 OMIM Tags
# 246700 NO ACMG
# On this line, there are 1 OMIM Tags
# 257220 NO ACMG
# On this line, there are 1 OMIM Tags
# 257220 NO ACMG
# On this line, there are 1 OMIM Tags
# 257220 NO ACMG

# %%
onlyomim = authoritative[authoritative['OMIMTAGS'] != "NA"]
onlyacmg = authoritative[authoritative['ACMGTAGS'] != "NA"]

# %% [markdown]
# ## NOTES FROM ALICE
#
# + Expert Panel, Practice Guideline, multiple submitters, no conflict
# + Check out information on drug response
#     + Add  Drug Response (clniincial signifigance > Drug Response)
# + Assembly
#     + Only Keep 38
