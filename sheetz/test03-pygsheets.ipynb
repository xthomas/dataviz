# %%
import pygsheets
import pandas as pd
from oauth2client.service_account import ServiceAccountCredentials 

# use creds to create a client to interact with the Google Drive API
# scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
# creds = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)

client = pygsheets.authorize(servicefile='./client_secret.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/oauth2client/clientsecrets.py in _validate_clientsecrets(clientsecrets_dict)
#      85     try:
# ---> 86         (client_type, client_info), = clientsecrets_dict.items()
#      87     except (ValueError, AttributeError):
#
# ValueError: too many values to unpack (expected 1)
#
# During handling of the above exception, another exception occurred:
#
# InvalidClientSecretsError                 Traceback (most recent call last)
# <ipython-input-3-5373d80321c3> in <module>()
#       7 # creds = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)
#       8
# ----> 9 client = pygsheets.authorize(servicefile='./client_secret.json')
#
# /anaconda3/lib/python3.6/site-packages/pygsheets/client.py in authorize(outh_file, outh_creds_store, outh_nonlocal, service_file, credentials, **client_kwargs)
#     590         elif outh_file:
#     591             credentials = get_outh_credentials(client_secret_file=outh_file, credential_dir=outh_creds_store,
# --> 592                                                outh_nonlocal=outh_nonlocal)
#     593         else:
#     594             raise AuthenticationError
#
# /anaconda3/lib/python3.6/site-packages/pygsheets/client.py in get_outh_credentials(client_secret_file, credential_dir, outh_nonlocal)
#     549             raise IOError(2, "Client secret file does not exist.", client_secret_file)
#     550         # execute flow
# --> 551         flow = client.flow_from_clientsecrets(client_secret_file, SCOPES)
#     552         flow.user_agent = 'pygsheets'
#     553         if lflags:
#
# /anaconda3/lib/python3.6/site-packages/oauth2client/_helpers.py in positional_wrapper(*args, **kwargs)
#     131                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     132                     logger.warning(message)
# --> 133             return wrapped(*args, **kwargs)
#     134         return positional_wrapper
#     135
#
# /anaconda3/lib/python3.6/site-packages/oauth2client/client.py in flow_from_clientsecrets(filename, scope, redirect_uri, message, cache, login_hint, device_uri, pkce, code_verifier, prompt)
#    2133     try:
#    2134         client_type, client_info = clientsecrets.loadfile(filename,
# -> 2135                                                           cache=cache)
#    2136         if client_type in (clientsecrets.TYPE_WEB,
#    2137                            clientsecrets.TYPE_INSTALLED):
#
# /anaconda3/lib/python3.6/site-packages/oauth2client/clientsecrets.py in loadfile(filename, cache)
#     163
#     164     if not cache:
# --> 165         return _loadfile(filename)
#     166
#     167     obj = cache.get(filename, namespace=_SECRET_NAMESPACE)
#
# /anaconda3/lib/python3.6/site-packages/oauth2client/clientsecrets.py in _loadfile(filename)
#     124         raise InvalidClientSecretsError('Error opening file', exc.filename,
#     125                                         exc.strerror, exc.errno)
# --> 126     return _validate_clientsecrets(obj)
#     127
#     128
#
# /anaconda3/lib/python3.6/site-packages/oauth2client/clientsecrets.py in _validate_clientsecrets(clientsecrets_dict)
#      87     except (ValueError, AttributeError):
#      88         raise InvalidClientSecretsError(
# ---> 89             _INVALID_FILE_FORMAT_MSG + ' '
#      90             'Expected a JSON object with a single property for a "web" or '
#      91             '"installed" application')
#
# InvalidClientSecretsError: Invalid file format. See https://developers.google.com/api-client-library/python/guide/aaa_client_secrets Expected a JSON object with a single property for a "web" or "installed" application

# %%
book = client.open("frequency_duration")
sheet_name ="Subset"
sheet = book.worksheet(Sheet_name)
df = pd.DataFrame(sheet.get_all_records())

# %%
df
# Out:
#                                               CHANNEL  FREQUENCY  IMPACT  \
# 0                Talking with colleagues face-to-face        2.0      35
# 1                Face-to-face meetings with sales rep        3.0      26
# 2                                     Dinner Meetings        1.0      21
# 3                        Online Professional Journals        9.0      17
# 4       Medical Website from an independent publisher        7.0      12
# 5   An independent publisher mobile app for physic...        9.5      11
# 6                                     Product Website        4.0       7
# 7                     Offline conferences (in person)        3.0      12
# 8                Live one-on-one online presentations        7.0       3
# 9              Self-guided online promotional program        7.5      16
# 10       Blogs, message boards and other social media        9.0       6
# 11                       Online or virtual conference        5.0       9
# 12              Pharma service portals for physicians        2.0       1
# 13             Email newsletter from the manufacturer        6.0       1
# 14                             Mobile app from Pharma        3.0       2
# 15               Online Webcast with KOL or Sales Rep        5.0       4
# 16                    Electronic health record system        9.0       2
#
#     INFLUENCE
# 0           5
# 1           2
# 2           1
# 3           5
# 4           3
# 5           4
# 6           3
# 7           2
# 8           1
# 9           1
# 10          2
# 11          3
# 12          4
# 13          3
# 14          3
# 15          1
# 16          4

# %%
data = {'Platoon': ['A','A','A','A','A','A','B','B','B','B','B','C','C','C','C','C'],
       'Casualties': [1,4,5,7,5,5,6,1,4,5,6,7,4,6,4,6]}
df2 = pd.DataFrame(data)
df2
# Out:
#     Casualties Platoon
# 0            1       A
# 1            4       A
# 2            5       A
# 3            7       A
# 4            5       A
# 5            5       A
# 6            6       B
# 7            1       B
# 8            4       B
# 9            5       B
# 10           6       B
# 11           7       C
# 12           4       C
# 13           6       C
# 14           4       C
# 15           6       C

# %%
newsheet = book.add_worksheet(title="A worksheet", rows="100", cols="20")

# %%
for row in df2.iterrows():
    newsheet.append_row(row[1].tolist())
