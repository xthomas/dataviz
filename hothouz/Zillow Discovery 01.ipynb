# %%
import pandas as pd

# %%
df = pd.read_csv('gs://datacamp-202518.appspot.com/data/re/zillow/DaysOnZillow_City.csv')

# %%
df.shape
# Out:
# (2714, 127)

# %%
df.head(10)
# Out:
#    SizeRank  RegionID    RegionName RegionType StateName  2010-01  2010-02  \
# 0         1      6181      New York       City        NY    196.0    190.0
# 1         2     12447   Los Angeles       City        CA    118.0    136.0
# 2         3     39051       Houston       City        TX    133.0    137.0
# 3         4     17426       Chicago       City        IL    186.0    180.5
# 4         5      6915   San Antonio       City        TX    101.0    110.0
# 5         6     13271  Philadelphia       City        PA    127.0    139.0
# 6         7     40326       Phoenix       City        AZ    108.0    109.0
# 7         8     18959     Las Vegas       City        NV    117.0    124.0
# 8         9     54296     San Diego       City        CA    103.0    112.0
# 9        10     38128        Dallas       City        TX    136.0    136.0
#
#    2010-03  2010-04  2010-05  ...  2019-05  2019-06  2019-07  2019-08  \
# 0    212.0    213.0    210.0  ...    175.0    157.0    153.5    155.0
# ...

# %%
ma = df[df["StateName"] == "MA"]

# %%
ma.shape
# Out:
# (93, 127)

# %%
ma
# Out:
#       SizeRank  RegionID    RegionName RegionType StateName  2010-01  2010-02  \
# 25          26     44269        Boston       City        MA    161.0    147.0
# 153        154     14724     Worcester       City        MA    149.5    142.0
# 195        196      7221   Springfield       City        MA      NaN      NaN
# 326        326     25659        Lowell       City        MA      NaN      NaN
# 333        333      3934     Cambridge       City        MA      NaN      NaN
# ...        ...       ...           ...        ...       ...      ...      ...
# 2455      2406    397669         Athol       City        MA      NaN      NaN
# 2513      2460     39684       Maynard       City        MA      NaN      NaN
# 2550      2497     25058       Harwich       City        MA      NaN      NaN
# 2596      2542    395473        Millis       City        MA      NaN      NaN
# 2701      2647    398808  Provincetown       City        MA      NaN      NaN
#
# ...

# %%
# Out:
#       SizeRank  RegionID    RegionName RegionType StateName  2010-01  2010-02  \
# 25          26     44269        Boston       City        MA    161.0    147.0
# 153        154     14724     Worcester       City        MA    149.5    142.0
# 195        196      7221   Springfield       City        MA      NaN      NaN
# 326        326     25659        Lowell       City        MA      NaN      NaN
# 333        333      3934     Cambridge       City        MA      NaN      NaN
# ...        ...       ...           ...        ...       ...      ...      ...
# 2455      2406    397669         Athol       City        MA      NaN      NaN
# 2513      2460     39684       Maynard       City        MA      NaN      NaN
# 2550      2497     25058       Harwich       City        MA      NaN      NaN
# 2596      2542    395473        Millis       City        MA      NaN      NaN
# 2701      2647    398808  Provincetown       City        MA      NaN      NaN
#
# ...
