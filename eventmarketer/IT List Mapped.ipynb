# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
import pandas as pd

# %%
raw='./data/itlist_mapping_02.csv'
df = pd.read_csv(raw)
df
# Out:
#                            COMPANY-NAME  Independent / Private / Owned  \
# 0                                  EMG3      Owned by TideSmart Global
# 1                           ENGINE SHOP  Owned by Bruin Sports Capital
# 2                               EPSILON                         public
# 3                  EVENT STRATEGY GROUP                        private
# 4                              EVENTAGE                    independent
# 5                              EVENTIVE                         public
# 6                             EVENTNEXT                         public
# 7                EXECUTIVE VISIONS INC.                    independent
# 8                           FACTORY 360                    independent
# 9                                  FCBX                         public
# 10                       FIRST PROTOCOL                        private
# 11                               FLUENT                        private
# 12                            FREEMANXP               Owned by Freeman
# 13                     FUSION MARKETING                        private
# 14                      GEOMETRY GLOBAL                         public
# 15                    GEORGE P. JOHNSON               Owned by Project
# 16                 GIANT STEP MARKETING                        private
# 17  GLOBAL EXPERIENCE SPECIALISTS (GES)                         public
# 18                        GMR MARKETING                         public
# 19                GO! EXPERIENCE DESIGN                        private
# 20                       GROW MARKETING                        private
# 21                         HAVAS IMPACT                         public
# 22                              HENRY V                        private
# 23                             IGNITION                 Owned by Havas
# 24                          IMAGINATION                        private
# 25                             IMG LIVE             Owned by WME | IMG
# 26              INFINITY MARKETING TEAM                    independent
# 27                             INFRARED        owned by Red Peak Group
# 28              INSPIRA MARKETING GROUP                    independent
# 29              INVISION COMMUNICATIONS                        private
# ..                                  ...                            ...
# 52                               MOSAIC                        private
# 53                               MOTIVE                        private
# 54                    MVP COLLABORATIVE                        private
# 55                        NA COLLECTIVE                        private
# 56                             NCOMPASS                        private
# 57                       NEWBRIDGE LIVE                        private
# 58                       NEXT MARKETING                    independent
# 59                                  NVE                        private
# 60                              OCTAGON                         public
# 61                ON BOARD EXPERIENTIAL                        private
# 62                          OPUS AGENCY                        private
# 63          PERFORMANCE MARKETING GROUP                        private
# 64                       PGW EXPERIENCE                   owned by CAA
# 65                             POP2LIFE                        private
# 66                           PROSCENIUM                     partership
# 67                     REDPEG MARKETING        private in a collective
# 68                                REVEL                        private
# 69                           REVOLUTION                    independent
# 70                                  SET                         public
# 71                    SOHO EXPERIENTIAL                        private
# 72                               SPARKS                        private
# 73                             SUPERFLY                        private
# 74                               SWITCH                        private
# 75                              SYNERGY                        private
# 76                     THE TAYLOR GROUP                        private
# 77                      TOUCH WORLDWIDE                        private
# 78                TRACK MARKETING GROUP                        private
# 79           UNITED ENTERTAINMENT GROUP               owned by Edelman
# 80                  THE VISIONARY GROUP                        private
# 81                            WASSERMAN                        private
#
#                CITY    STATE EMPLOYEE-RANGE  EMPLOYEE-AVERAGE COUNTRY
# 0          Falmouth       ME          11-50              30.5     USA
# 1                NY       NY         50-200             125.0     USA
# 2            Irving       TX           500+             500.0     USA
# 3          Broomall       PA          11-50              30.5     USA
# 4      South Orange       NJ          11-50              30.5     USA
# 5                NY       NY          11-50              30.5     USA
# 6        Lake Orion       MI          11-50              30.5     USA
# 7         Norcross        GA          11-50              30.5     USA
# 8                NY       NY         50-200             125.0     USA
# 9           Chicago       IL          11-50              30.5     USA
# 10           London  England            180             180.0      UK
# 11         Colombia       SC          11-50              30.5     USA
# 12           Dallas       TX         50-200             125.0     USA
# 13        St. Louis       MO          11-50              30.5     USA
# 14               NY       NY          1000+            1000.0     USA
# 15     Auburn Hills       MI          1000+            1000.0     USA
# 16         Brooklyn       NY          11-50              30.5     USA
# 17        Las Vegas       NV           500+             500.0     USA
# 18      New Berlin        WI           500+             500.0     USA
# 19          Atlanta       GA          11-50              30.5     USA
# 20    san francisco       CA          11-50              30.5     USA
# 21          Chicago       IL         50-200             125.0     USA
# 22         Portland       OR         50-200             125.0     USA
# 23          Atlanta       GA         50-200             125.0     USA
# 24           London  England           500+             500.0      UK
# 25         Norcross       GA         50-200             125.0     USA
# 26      Culver City       CA         50-200             125.0     USA
# 27               NY       NY          11-50              30.5     USA
# 28          Norwalk       CT        200-500             350.0     USA
# 29     Walnut Creek       CA         50-200             125.0     USA
# ..              ...      ...            ...               ...     ...
# 52      Mississauga  Ontario          1000+            1000.0  CANADA
# 53               NY       NY         50-200             125.0     USA
# 54  Madison Heights       MI          11-50              30.5     USA
# 55               NY       NY          11-50              30.5     USA
# 56   West Hollywood       CA         50-200             125.0     USA
# 57         Portland       ME          11-50              30.5     USA
# 58          Atlanta       GA          11-50              30.5     USA
# 59    Beverly Hills       CA             17              17.0     USA
# 60           McLean       VA            800             800.0     USA
# 61        Sausalito       CA         50-200             125.0     USA
# 62        Beaverton       OR         50-200             125.0     USA
# 63     Indianapolis       IN         50-200             125.0     USA
# 64      Los Angeles       CA         50-200             125.0     USA
# 65               NY       NY          11-50              30.5     USA
# 66               NY       NY          11-50              30.5     USA
# 67       Alexandria       VA         50-200             125.0     USA
# 68         Muskegon       MI          11-50              30.5     USA
# 69          Chicago       IL         50-200             125.0     USA
# 70         Portland       OR         50-200             125.0     USA
# 71               NY       NY          11-50              30.5     USA
# 72     Philadelphia       PA        200-500             350.0     USA
# 73               NY       NY         50-200             125.0     USA
# 74        st. louis       MO         50-200             125.0     USA
# 75            Ocean       NJ         50-200             125.0     USA
# 76         Brampton  Ontario        200-500             350.0  CANADA
# 77          Seattle       WA         50-200             125.0     USA
# 78               NY       NY          11-50              30.5     USA
# 79               NY       NY         50-200             125.0     USA
# 80      Los Angeles       CA             35              35.0     USA
# 81      Los Angeles       CA           500+             500.0     USA
#
# [82 rows x 7 columns]

# %%
dfusa = df[(df["COUNTRY"]=="USA")]
dfusa
# Out:
#                            COMPANY-NAME  Independent / Private / Owned  \
# 0                                  EMG3      Owned by TideSmart Global
# 1                           ENGINE SHOP  Owned by Bruin Sports Capital
# 2                               EPSILON                         public
# 3                  EVENT STRATEGY GROUP                        private
# 4                              EVENTAGE                    independent
# 5                              EVENTIVE                         public
# 6                             EVENTNEXT                         public
# 7                EXECUTIVE VISIONS INC.                    independent
# 8                           FACTORY 360                    independent
# 9                                  FCBX                         public
# 11                               FLUENT                        private
# 12                            FREEMANXP               Owned by Freeman
# 13                     FUSION MARKETING                        private
# 14                      GEOMETRY GLOBAL                         public
# 15                    GEORGE P. JOHNSON               Owned by Project
# 16                 GIANT STEP MARKETING                        private
# 17  GLOBAL EXPERIENCE SPECIALISTS (GES)                         public
# 18                        GMR MARKETING                         public
# 19                GO! EXPERIENCE DESIGN                        private
# 20                       GROW MARKETING                        private
# 21                         HAVAS IMPACT                         public
# 22                              HENRY V                        private
# 23                             IGNITION                 Owned by Havas
# 25                             IMG LIVE             Owned by WME | IMG
# 26              INFINITY MARKETING TEAM                    independent
# 27                             INFRARED        owned by Red Peak Group
# 28              INSPIRA MARKETING GROUP                    independent
# 29              INVISION COMMUNICATIONS                        private
# 30                                INVNT                         public
# 31                JACK MORTON WORLDWIDE                         public
# ..                                  ...                            ...
# 50               MODERNE COMMUNICATIONS                        private
# 51                   MOMENTUM WORLDWIDE                         public
# 53                               MOTIVE                        private
# 54                    MVP COLLABORATIVE                        private
# 55                        NA COLLECTIVE                        private
# 56                             NCOMPASS                        private
# 57                       NEWBRIDGE LIVE                        private
# 58                       NEXT MARKETING                    independent
# 59                                  NVE                        private
# 60                              OCTAGON                         public
# 61                ON BOARD EXPERIENTIAL                        private
# 62                          OPUS AGENCY                        private
# 63          PERFORMANCE MARKETING GROUP                        private
# 64                       PGW EXPERIENCE                   owned by CAA
# 65                             POP2LIFE                        private
# 66                           PROSCENIUM                     partership
# 67                     REDPEG MARKETING        private in a collective
# 68                                REVEL                        private
# 69                           REVOLUTION                    independent
# 70                                  SET                         public
# 71                    SOHO EXPERIENTIAL                        private
# 72                               SPARKS                        private
# 73                             SUPERFLY                        private
# 74                               SWITCH                        private
# 75                              SYNERGY                        private
# 77                      TOUCH WORLDWIDE                        private
# 78                TRACK MARKETING GROUP                        private
# 79           UNITED ENTERTAINMENT GROUP               owned by Edelman
# 80                  THE VISIONARY GROUP                        private
# 81                            WASSERMAN                        private
#
#                 CITY STATE EMPLOYEE-RANGE  EMPLOYEE-AVERAGE COUNTRY
# 0           Falmouth    ME          11-50              30.5     USA
# 1                 NY    NY         50-200             125.0     USA
# 2             Irving    TX           500+             500.0     USA
# 3           Broomall    PA          11-50              30.5     USA
# 4       South Orange    NJ          11-50              30.5     USA
# 5                 NY    NY          11-50              30.5     USA
# 6         Lake Orion    MI          11-50              30.5     USA
# 7          Norcross     GA          11-50              30.5     USA
# 8                 NY    NY         50-200             125.0     USA
# 9            Chicago    IL          11-50              30.5     USA
# 11          Colombia    SC          11-50              30.5     USA
# 12            Dallas    TX         50-200             125.0     USA
# 13         St. Louis    MO          11-50              30.5     USA
# 14                NY    NY          1000+            1000.0     USA
# 15      Auburn Hills    MI          1000+            1000.0     USA
# 16          Brooklyn    NY          11-50              30.5     USA
# 17         Las Vegas    NV           500+             500.0     USA
# 18       New Berlin     WI           500+             500.0     USA
# 19           Atlanta    GA          11-50              30.5     USA
# 20     san francisco    CA          11-50              30.5     USA
# 21           Chicago    IL         50-200             125.0     USA
# 22          Portland    OR         50-200             125.0     USA
# 23           Atlanta    GA         50-200             125.0     USA
# 25          Norcross    GA         50-200             125.0     USA
# 26       Culver City    CA         50-200             125.0     USA
# 27                NY    NY          11-50              30.5     USA
# 28           Norwalk    CT        200-500             350.0     USA
# 29      Walnut Creek    CA         50-200             125.0     USA
# 30                NY    NY         50-200             125.0     USA
# 31                NY    NY           500+             500.0     USA
# ..               ...   ...            ...               ...     ...
# 50  Rockville Centre    NY          11-50              30.5     USA
# 51                NY    NY          1000+            1000.0     USA
# 53                NY    NY         50-200             125.0     USA
# 54   Madison Heights    MI          11-50              30.5     USA
# 55                NY    NY          11-50              30.5     USA
# 56    West Hollywood    CA         50-200             125.0     USA
# 57          Portland    ME          11-50              30.5     USA
# 58           Atlanta    GA          11-50              30.5     USA
# 59     Beverly Hills    CA             17              17.0     USA
# 60            McLean    VA            800             800.0     USA
# 61         Sausalito    CA         50-200             125.0     USA
# 62         Beaverton    OR         50-200             125.0     USA
# 63      Indianapolis    IN         50-200             125.0     USA
# 64       Los Angeles    CA         50-200             125.0     USA
# 65                NY    NY          11-50              30.5     USA
# 66                NY    NY          11-50              30.5     USA
# 67        Alexandria    VA         50-200             125.0     USA
# 68          Muskegon    MI          11-50              30.5     USA
# 69           Chicago    IL         50-200             125.0     USA
# 70          Portland    OR         50-200             125.0     USA
# 71                NY    NY          11-50              30.5     USA
# 72      Philadelphia    PA        200-500             350.0     USA
# 73                NY    NY         50-200             125.0     USA
# 74         st. louis    MO         50-200             125.0     USA
# 75             Ocean    NJ         50-200             125.0     USA
# 77           Seattle    WA         50-200             125.0     USA
# 78                NY    NY          11-50              30.5     USA
# 79                NY    NY         50-200             125.0     USA
# 80       Los Angeles    CA             35              35.0     USA
# 81       Los Angeles    CA           500+             500.0     USA
#
# [77 rows x 7 columns]

# %%
scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['STATE'],
        z = dfusa['EMPLOYEE-AVERAGE'].astype(float),
        locationmode = 'USA-states',
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
    ) ]

# %%
layout = dict(
        title = 'Experential Agency Revenue by Statee<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )

fig = go.Figure(data=data, layout=layout)

# %%
url = py.plot(fig, filename='experiential-map')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x10d36bcc0>: Failed to establish a new connection: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     648             retries = retries.increment(method, url, error=e, _pool=self,
# --> 649                                         _stacktrace=sys.exc_info()[2])
#     650             retries.sleep()
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     375         if new_retry.is_exhausted():
# --> 376             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     377
#
# MaxRetryError: HTTPSConnectionPool(host='plot.ly', port=443): Max retries exceeded with url: /clientresp (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x10d36bcc0>: Failed to establish a new connection: [Errno 60] Operation timed out',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /Users/hanuman/anaconda/lib/python3.6/site-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      77     try:
# ---> 78         response = requests.request(method, url, **kwargs)
#      79     except RequestException as e:
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#
# ConnectionError: HTTPSConnectionPool(host='plot.ly', port=443): Max retries exceeded with url: /clientresp (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x10d36bcc0>: Failed to establish a new connection: [Errno 60] Operation timed out',))
#
# During handling of the above exception, another exception occurred:
#
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-6-f13d093b7f0b> in <module>()
# ----> 1 url = py.plot(fig, filename='experiential-map')
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     222     data = fig.get('data', [])
#     223     plot_options['layout'] = fig.get('layout', {})
# --> 224     response = v1.clientresp(data, **plot_options)
#     225
#     226     # Check if the url needs a secret key
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /Users/hanuman/anaconda/lib/python3.6/site-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      83         status_code = response.status_code if response else None
#      84         content = response.content if response else 'No content'
# ---> 85         raise exceptions.PlotlyRequestError(message, status_code, content)
#      86     validate_response(response)
#      87     return response
#
# PlotlyRequestError: No message
